# %%
# Import the random module.
import pandas as pd
import numpy as np
import requests
import gmaps

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6d755a1ede82d8c6d8fbbafc342987ae"
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6d755a1ede82d8c6d8fbbafc342987ae

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_wind = city_weather["wind"]["speed"]
        city_clouds = city_weather["clouds"]["all"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Wind Speed": city_wind,
                          "Cloudiness": city_clouds,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 16 | fortuna
# Processing Record 2 of Set 16 | cordoba
# Processing Record 3 of Set 16 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 16 | mahebourg
# Processing Record 5 of Set 16 | arraial do cabo
# Processing Record 6 of Set 16 | kodiak
# Processing Record 7 of Set 16 | san policarpo
# Processing Record 8 of Set 16 | hermanus
# Processing Record 9 of Set 16 | vaini
# Processing Record 10 of Set 16 | nova olimpia
# Processing Record 11 of Set 16 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 16 | nanortalik
# Processing Record 13 of Set 16 | punta arenas
# Processing Record 14 of Set 16 | geraldton
# Processing Record 15 of Set 16 | college
# Processing Record 16 of Set 16 | atuona
# Processing Record 17 of Set 16 | alofi
# Processing Record 18 of Set 16 | rikitea
# Processing Record 19 of Set 16 | castro
# Processing Record 20 of Set 16 | cape town
# Processing Record 21 of Set 16 | tasiilaq
# Processing Record 22 of Set 16 | saint-louis
# Processing Record 23 of Set 16 | hobart
# Processing Record 24 of Set 16 | kirakira
# Processing Record 25 of Set 16 | souillac
# Processing Record 26 of Set 16 | ushuaia
# Processing Record 27 of Set 16 | sokone
# Processing Record 28 of Set 16 | dorado
# Processing Record 29 of Set 16 | pocoes
# Processing Record 30 of Set 16 | san cristobal
# Processing Record 31 of Set 16 | archidona
# Processing Record 32 of Set 16 | east london
# Processing Record 33 of Set 16 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 16 | nikolskoye
# Processing Record 35 of Set 16 | kununurra
# Processing Record 36 of Set 16 | ushumun
# Processing Record 37 of Set 16 | albany
# Processing Record 38 of Set 16 | busselton
# Processing Record 39 of Set 16 | grindavik
# Processing Record 40 of Set 16 | port alfred
# Processing Record 41 of Set 16 | krasnoselkup
# Processing Record 42 of Set 16 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 43 of Set 16 | butaritari
# Processing Record 44 of Set 16 | nhulunbuy
# Processing Record 45 of Set 16 | qaanaaq
# Processing Record 46 of Set 16 | bystrice nad pernstejnem
# Processing Record 47 of Set 16 | sladkovo
# Processing Record 48 of Set 16 | puerto ayora
# Processing Record 49 of Set 16 | mweka
# Processing Record 50 of Set 16 | kruisfontein
# Processing Record 1 of Set 17 | airai
# Processing Record 2 of Set 17 | roma
# Processing Record 3 of Set 17 | saskylakh
# Processing Record 4 of Set 17 | ribeira grande
# Processing Record 5 of Set 17 | kurtalan
# Processing Record 6 of Set 17 | cloquet
# Processing Record 7 of Set 17 | yerofey pavlovich
# Processing Record 8 of Set 17 | mataura
# Processing Record 9 of Set 17 | klaksvik
# Processing Record 10 of Set 17 | tripoli
# Processing Record 11 of Set 17 | lebu
# Processing Record 12 of Set 17 | khatanga
# Processing Record 13 of Set 17 | victoria
# Processing Record 14 of Set 17 | abu dhabi
# Processing Record 15 of Set 17 | biak
# Processing Record 16 of Set 17 | yerbogachen
# Processing Record 17 of Set 17 | mogadishu
# Processing Record 18 of Set 17 | boyolangu
# Processing Record 19 of Set 17 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 17 | talnakh
# Processing Record 21 of Set 17 | shakawe
# Processing Record 22 of Set 17 | bhinmal
# Processing Record 23 of Set 17 | lavrentiya
# Processing Record 24 of Set 17 | gravdal
# Processing Record 25 of Set 17 | gornopravdinsk
# Processing Record 26 of Set 17 | bambous virieux
# Processing Record 27 of Set 17 | shenjiamen
# Processing Record 28 of Set 17 | sao filipe
# Processing Record 29 of Set 17 | durazno
# Processing Record 30 of Set 17 | kyabram
# Processing Record 31 of Set 17 | tuatapere
# Processing Record 32 of Set 17 | pisco
# Processing Record 33 of Set 17 | aswan
# Processing Record 34 of Set 17 | zinder
# Processing Record 35 of Set 17 | dikson
# Processing Record 36 of Set 17 | hamilton
# Processing Record 37 of Set 17 | puksoozero
# Processing Record 38 of Set 17 | chabahar
# Processing Record 39 of Set 17 | ban nahin
# Processing Record 40 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 17 | usinsk
# Processing Record 42 of Set 17 | kavaratti
# Processing Record 43 of Set 17 | saint george
# Processing Record 44 of Set 17 | new norfolk
# Processing Record 45 of Set 17 | sandakan
# Processing Record 46 of Set 17 | longyearbyen
# Processing Record 47 of Set 17 | yellowknife
# Processing Record 48 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 49 of Set 17 | aguimes
# Processing Record 50 of Set 17 | rawson
# Processing Record 1 of Set 18 | hofn
# Processing Record 2 of Set 18 | zhanakorgan
# Processing Record 3 of Set 18 | whyalla
# Processing Record 4 of Set 18 | port elizabeth
# Processing Record 5 of Set 18 | cozumel
# Processing Record 6 of Set 18 | nome
# Processing Record 7 of Set 18 | chokurdakh
# Processing Record 8 of Set 18 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 18 | hilo
# Processing Record 10 of Set 18 | luderitz
# Processing Record 11 of Set 18 | hithadhoo
# Processing Record 12 of Set 18 | barrow
# Processing Record 13 of Set 18 | oinoussai
# City not found. Skipping...
# Processing Record 14 of Set 18 | ouadda
# Processing Record 15 of Set 18 | kapaa
# Processing Record 16 of Set 18 | labuan
# Processing Record 17 of Set 18 | yar-sale
# Processing Record 18 of Set 18 | bredasdorp
# Processing Record 19 of Set 18 | artyom
# Processing Record 20 of Set 18 | tiksi
# Processing Record 21 of Set 18 | carnarvon
# Processing Record 22 of Set 18 | ruston
# Processing Record 23 of Set 18 | barranca
# Processing Record 24 of Set 18 | mount gambier
# Processing Record 25 of Set 18 | vozhega
# Processing Record 26 of Set 18 | brownsville
# Processing Record 27 of Set 18 | coetupo
# City not found. Skipping...
# Processing Record 28 of Set 18 | bluff
# Processing Record 29 of Set 18 | saint-philippe
# Processing Record 30 of Set 18 | miraflores
# Processing Record 31 of Set 18 | ilulissat
# Processing Record 32 of Set 18 | betioky
# Processing Record 33 of Set 18 | codrington
# Processing Record 34 of Set 18 | shingu
# Processing Record 35 of Set 18 | mandali
# Processing Record 36 of Set 18 | lata
# Processing Record 37 of Set 18 | margate
# Processing Record 38 of Set 18 | erenhot
# Processing Record 39 of Set 18 | araouane
# Processing Record 40 of Set 18 | tuktoyaktuk
# Processing Record 41 of Set 18 | san andres
# Processing Record 42 of Set 18 | verkhnevilyuysk
# Processing Record 43 of Set 18 | mar del plata
# Processing Record 44 of Set 18 | vardo
# Processing Record 45 of Set 18 | ardakan
# Processing Record 46 of Set 18 | pecos
# Processing Record 47 of Set 18 | chenghai
# Processing Record 48 of Set 18 | asau
# Processing Record 49 of Set 18 | komsomolskiy
# Processing Record 50 of Set 18 | cabo san lucas
# Processing Record 1 of Set 19 | okitipupa
# Processing Record 2 of Set 19 | pevek
# Processing Record 3 of Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 19 | bambanglipuro
# Processing Record 5 of Set 19 | yuxia
# Processing Record 6 of Set 19 | sobolevo
# Processing Record 7 of Set 19 | thompson
# Processing Record 8 of Set 19 | ancud
# Processing Record 9 of Set 19 | cidreira
# Processing Record 10 of Set 19 | chuy
# Processing Record 11 of Set 19 | celestun
# Processing Record 12 of Set 19 | nizhniy tsasuchey
# Processing Record 13 of Set 19 | leningradskiy
# Processing Record 14 of Set 19 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 19 | kralendijk
# Processing Record 16 of Set 19 | kaeo
# Processing Record 17 of Set 19 | praia da vitoria
# Processing Record 18 of Set 19 | cedar city
# Processing Record 19 of Set 19 | salalah
# Processing Record 20 of Set 19 | georgetown
# Processing Record 21 of Set 19 | naze
# Processing Record 22 of Set 19 | cherskiy
# Processing Record 23 of Set 19 | saint anthony
# Processing Record 24 of Set 19 | dingle
# Processing Record 25 of Set 19 | narsaq
# Processing Record 26 of Set 19 | meulaboh
# Processing Record 27 of Set 19 | vao
# Processing Record 28 of Set 19 | tiarei
# Processing Record 29 of Set 19 | mudgee
# Processing Record 30 of Set 19 | tobermory
# Processing Record 31 of Set 19 | sabibah
# City not found. Skipping...
# Processing Record 32 of Set 19 | ponta do sol
# Processing Record 33 of Set 19 | zhicheng
# Processing Record 34 of Set 19 | axim
# Processing Record 35 of Set 19 | bonavista
# Processing Record 36 of Set 19 | upernavik
# Processing Record 37 of Set 19 | faanui
# Processing Record 38 of Set 19 | cap malheureux
# Processing Record 39 of Set 19 | gubkinskiy
# Processing Record 40 of Set 19 | grajau
# Processing Record 41 of Set 19 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 19 | semarang
# Processing Record 43 of Set 19 | manturovo
# Processing Record 44 of Set 19 | kiruna
# Processing Record 45 of Set 19 | swinoujscie
# Processing Record 46 of Set 19 | mangrol
# Processing Record 47 of Set 19 | norman wells
# Processing Record 48 of Set 19 | calabozo
# Processing Record 49 of Set 19 | aranos
# Processing Record 50 of Set 19 | ninh binh
# Processing Record 1 of Set 20 | kaitangata
# Processing Record 2 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 20 | bengkulu
# Processing Record 4 of Set 20 | mezen
# Processing Record 5 of Set 20 | jurmala
# Processing Record 6 of Set 20 | sompeta
# Processing Record 7 of Set 20 | faya
# Processing Record 8 of Set 20 | stromness
# Processing Record 9 of Set 20 | ossora
# Processing Record 10 of Set 20 | trelew
# Processing Record 11 of Set 20 | torbay
# Processing Record 12 of Set 20 | canaries
# Processing Record 13 of Set 20 | manta
# Processing Record 14 of Set 20 | avanigadda
# Processing Record 15 of Set 20 | hanzhong
# Processing Record 16 of Set 20 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 20 | barcelos
# Processing Record 18 of Set 20 | shakhtinsk
# Processing Record 19 of Set 20 | carballo
# Processing Record 20 of Set 20 | linares
# Processing Record 21 of Set 20 | alta floresta
# Processing Record 22 of Set 20 | canutama
# Processing Record 23 of Set 20 | portland
# Processing Record 24 of Set 20 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 20 | te anau
# Processing Record 26 of Set 20 | fallon
# Processing Record 27 of Set 20 | payo
# Processing Record 28 of Set 20 | hualmay
# Processing Record 29 of Set 20 | grand gaube
# Processing Record 30 of Set 20 | springdale
# Processing Record 31 of Set 20 | heilbron
# Processing Record 32 of Set 20 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 20 | jamestown
# Processing Record 34 of Set 20 | haverfordwest
# Processing Record 35 of Set 20 | buala
# Processing Record 36 of Set 20 | salym
# Processing Record 37 of Set 20 | puerto del rosario
# Processing Record 38 of Set 20 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 20 | ponta delgada
# Processing Record 40 of Set 20 | tabas
# Processing Record 41 of Set 20 | lompoc
# Processing Record 42 of Set 20 | tolaga bay
# Processing Record 43 of Set 20 | khandbari
# Processing Record 44 of Set 20 | avarua
# Processing Record 45 of Set 20 | shagonar
# Processing Record 46 of Set 20 | bethel
# Processing Record 47 of Set 20 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 20 | raghunathpur
# Processing Record 49 of Set 20 | marsh harbour
# Processing Record 50 of Set 20 | tual
# Processing Record 1 of Set 21 | hobyo
# Processing Record 2 of Set 21 | cayenne
# Processing Record 3 of Set 21 | araguatins
# City not found. Skipping...
# Processing Record 4 of Set 21 | las vegas
# Processing Record 5 of Set 21 | tazmalt
# Processing Record 6 of Set 21 | roald
# Processing Record 7 of Set 21 | camopi
# Processing Record 8 of Set 21 | juneau
# Processing Record 9 of Set 21 | slave lake
# Processing Record 10 of Set 21 | mercedes
# Processing Record 11 of Set 21 | kashi
# Processing Record 12 of Set 21 | provideniya
# Processing Record 13 of Set 21 | ketchikan
# Processing Record 14 of Set 21 | ambilobe
# Processing Record 15 of Set 21 | alekseyevka
# Processing Record 16 of Set 21 | san patricio
# Processing Record 17 of Set 21 | kamiiso
# Processing Record 18 of Set 21 | victor harbor
# Processing Record 19 of Set 21 | uk
# City not found. Skipping...
# Processing Record 20 of Set 21 | anda
# Processing Record 21 of Set 21 | rio grande
# Processing Record 22 of Set 21 | pochutla
# Processing Record 23 of Set 21 | zhigansk
# Processing Record 24 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 21 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 21 | altay
# Processing Record 27 of Set 21 | gat
# Processing Record 28 of Set 21 | santa isabel do rio negro
# Processing Record 29 of Set 21 | valdivia
# Processing Record 30 of Set 21 | bay roberts
# Processing Record 31 of Set 21 | mamlyutka
# Processing Record 32 of Set 21 | laguna
# Processing Record 33 of Set 21 | bafra
# Processing Record 34 of Set 21 | saint-augustin
# Processing Record 35 of Set 21 | culipapa
# City not found. Skipping...
# Processing Record 36 of Set 21 | high level
# Processing Record 37 of Set 21 | pyaozerskiy
# Processing Record 38 of Set 21 | hasaki
# Processing Record 39 of Set 21 | kavieng
# Processing Record 40 of Set 21 | dutse
# Processing Record 41 of Set 21 | pietarsaari
# Processing Record 42 of Set 21 | los llanos de aridane
# Processing Record 43 of Set 21 | jumla
# Processing Record 44 of Set 21 | flinders
# Processing Record 45 of Set 21 | esperance
# Processing Record 46 of Set 21 | knysna
# Processing Record 47 of Set 21 | haines junction
# Processing Record 48 of Set 21 | stornoway
# Processing Record 49 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 21 | sulya
# Processing Record 1 of Set 22 | ortigueira
# Processing Record 2 of Set 22 | monroe
# Processing Record 3 of Set 22 | la ronge
# Processing Record 4 of Set 22 | muros
# Processing Record 5 of Set 22 | sibolga
# Processing Record 6 of Set 22 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 22 | tornio
# Processing Record 8 of Set 22 | porto novo
# Processing Record 9 of Set 22 | elizabeth city
# Processing Record 10 of Set 22 | zabaykalsk
# Processing Record 11 of Set 22 | saldanha
# Processing Record 12 of Set 22 | teguldet
# Processing Record 13 of Set 22 | gizo
# Processing Record 14 of Set 22 | scarborough
# Processing Record 15 of Set 22 | kapit
# Processing Record 16 of Set 22 | broome
# Processing Record 17 of Set 22 | mountain home
# Processing Record 18 of Set 22 | vestmannaeyjar
# Processing Record 19 of Set 22 | el faiyum
# City not found. Skipping...
# Processing Record 20 of Set 22 | minab
# Processing Record 21 of Set 22 | takoradi
# Processing Record 22 of Set 22 | vila
# Processing Record 23 of Set 22 | rodez
# Processing Record 24 of Set 22 | phonhong
# Processing Record 25 of Set 22 | ivankiv
# Processing Record 26 of Set 22 | kostomuksha
# Processing Record 27 of Set 22 | kloulklubed
# Processing Record 28 of Set 22 | ostrovnoy
# Processing Record 29 of Set 22 | eureka
# Processing Record 30 of Set 22 | curvelo
# Processing Record 31 of Set 22 | lokosovo
# Processing Record 32 of Set 22 | muravlenko
# Processing Record 33 of Set 22 | katsuura
# Processing Record 34 of Set 22 | bury saint edmunds
# City not found. Skipping...
# Processing Record 35 of Set 22 | teya
# Processing Record 36 of Set 22 | bintulu
# Processing Record 37 of Set 22 | ksenyevka
# City not found. Skipping...
# Processing Record 38 of Set 22 | sinkat
# City not found. Skipping...
# Processing Record 39 of Set 22 | alyangula
# Processing Record 40 of Set 22 | mazamet
# Processing Record 41 of Set 22 | toora-khem
# Processing Record 42 of Set 22 | adre
# Processing Record 43 of Set 22 | eirunepe
# Processing Record 44 of Set 22 | petropavl
# Processing Record 45 of Set 22 | dodge city
# Processing Record 46 of Set 22 | barroquinha
# Processing Record 47 of Set 22 | porto torres
# Processing Record 48 of Set 22 | christchurch
# Processing Record 49 of Set 22 | matara
# Processing Record 50 of Set 22 | fairbanks
# Processing Record 1 of Set 23 | coquimbo
# Processing Record 2 of Set 23 | paita
# Processing Record 3 of Set 23 | gualaceo
# Processing Record 4 of Set 23 | gazni
# City not found. Skipping...
# Processing Record 5 of Set 23 | mori
# Processing Record 6 of Set 23 | jatiroto
# Processing Record 7 of Set 23 | mayo
# Processing Record 8 of Set 23 | coihaique
# Processing Record 9 of Set 23 | hosur
# Processing Record 10 of Set 23 | pemba
# Processing Record 11 of Set 23 | namatanai
# Processing Record 12 of Set 23 | arys
# Processing Record 13 of Set 23 | kutum
# Processing Record 14 of Set 23 | sitka
# Processing Record 15 of Set 23 | severo-kurilsk
# Processing Record 16 of Set 23 | beidao
# Processing Record 17 of Set 23 | waipawa
# Processing Record 18 of Set 23 | burica
# City not found. Skipping...
# Processing Record 19 of Set 23 | viedma
# Processing Record 20 of Set 23 | tamano
# Processing Record 21 of Set 23 | rongcheng
# Processing Record 22 of Set 23 | kalemie
# Processing Record 23 of Set 23 | sarti
# Processing Record 24 of Set 23 | sterling
# Processing Record 25 of Set 23 | svarstad
# Processing Record 26 of Set 23 | labuhan
# Processing Record 27 of Set 23 | campbell river
# Processing Record 28 of Set 23 | hervey bay
# Processing Record 29 of Set 23 | stykkisholmur
# Processing Record 30 of Set 23 | gamboma
# Processing Record 31 of Set 23 | ruatoria
# City not found. Skipping...
# Processing Record 32 of Set 23 | phan thiet
# Processing Record 33 of Set 23 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 23 | richards bay
# Processing Record 35 of Set 23 | mildura
# Processing Record 36 of Set 23 | kolokani
# Processing Record 37 of Set 23 | okhotsk
# Processing Record 38 of Set 23 | nargana
# Processing Record 39 of Set 23 | kalmunai
# Processing Record 40 of Set 23 | sibu
# Processing Record 41 of Set 23 | sosnovo-ozerskoye
# Processing Record 42 of Set 23 | kaduna
# Processing Record 43 of Set 23 | matatlan
# City not found. Skipping...
# Processing Record 44 of Set 23 | caravelas
# Processing Record 45 of Set 23 | yeppoon
# Processing Record 46 of Set 23 | kristiansund
# Processing Record 47 of Set 23 | san quintin
# Processing Record 48 of Set 23 | giyon
# Processing Record 49 of Set 23 | unai
# Processing Record 50 of Set 23 | honningsvag
# Processing Record 1 of Set 24 | husavik
# Processing Record 2 of Set 24 | salinopolis
# Processing Record 3 of Set 24 | maglajani
# Processing Record 4 of Set 24 | japura
# Processing Record 5 of Set 24 | ritchie
# Processing Record 6 of Set 24 | touros
# Processing Record 7 of Set 24 | samarai
# Processing Record 8 of Set 24 | manokwari
# Processing Record 9 of Set 24 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 24 | purpe
# Processing Record 11 of Set 24 | chicama
# Processing Record 12 of Set 24 | lagos
# Processing Record 13 of Set 24 | vangaindrano
# Processing Record 14 of Set 24 | san jose
# Processing Record 15 of Set 24 | doha
# Processing Record 16 of Set 24 | sioux lookout
# Processing Record 17 of Set 24 | sisimiut
# Processing Record 18 of Set 24 | polunochnoye
# Processing Record 19 of Set 24 | matay
# Processing Record 20 of Set 24 | hanting
# Processing Record 21 of Set 24 | omaruru
# Processing Record 22 of Set 24 | maceio
# Processing Record 23 of Set 24 | bessemer
# Processing Record 24 of Set 24 | aripuana
# Processing Record 25 of Set 24 | andilamena
# Processing Record 26 of Set 24 | palm coast
# Processing Record 27 of Set 24 | taua
# Processing Record 28 of Set 24 | kahului
# Processing Record 29 of Set 24 | lorengau
# Processing Record 30 of Set 24 | avera
# Processing Record 31 of Set 24 | westerland
# Processing Record 32 of Set 24 | aklavik
# Processing Record 33 of Set 24 | lucea
# Processing Record 34 of Set 24 | ebano
# City not found. Skipping...
# Processing Record 35 of Set 24 | constitucion
# Processing Record 36 of Set 24 | at-bashi
# Processing Record 37 of Set 24 | omboue
# Processing Record 38 of Set 24 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 24 | huarmey
# Processing Record 40 of Set 24 | culebra
# Processing Record 41 of Set 24 | zapolyarnyy
# Processing Record 42 of Set 24 | mossendjo
# Processing Record 43 of Set 24 | montepuez
# Processing Record 44 of Set 24 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 24 | kijaba
# City not found. Skipping...
# Processing Record 46 of Set 24 | mamou
# Processing Record 47 of Set 24 | abalak
# Processing Record 48 of Set 24 | isangel
# Processing Record 49 of Set 24 | alekseyevsk
# Processing Record 50 of Set 24 | sterlibashevo
# Processing Record 1 of Set 25 | beloha
# Processing Record 2 of Set 25 | vila velha
# Processing Record 3 of Set 25 | vestmanna
# Processing Record 4 of Set 25 | cukai
# Processing Record 5 of Set 25 | bereda
# Processing Record 6 of Set 25 | lar gerd
# City not found. Skipping...
# Processing Record 7 of Set 25 | yining
# Processing Record 8 of Set 25 | old saybrook
# Processing Record 9 of Set 25 | bagdarin
# Processing Record 10 of Set 25 | trincomalee
# Processing Record 11 of Set 25 | mahajanga
# Processing Record 12 of Set 25 | holt
# Processing Record 13 of Set 25 | ayan
# Processing Record 14 of Set 25 | talara
# Processing Record 15 of Set 25 | vaitape
# Processing Record 16 of Set 25 | tapaua
# City not found. Skipping...
# Processing Record 17 of Set 25 | sechura
# Processing Record 18 of Set 25 | wlodawa
# Processing Record 19 of Set 25 | progreso
# Processing Record 20 of Set 25 | svetlogorsk
# Processing Record 21 of Set 25 | wenzhou
# Processing Record 22 of Set 25 | opuwo
# Processing Record 23 of Set 25 | itarema
# Processing Record 24 of Set 25 | port-gentil
# Processing Record 25 of Set 25 | maua
# Processing Record 26 of Set 25 | nicoya
# Processing Record 27 of Set 25 | natal
# Processing Record 28 of Set 25 | jega
# Processing Record 29 of Set 25 | staryy nadym
# Processing Record 30 of Set 25 | karratha
# Processing Record 31 of Set 25 | mineiros
# Processing Record 32 of Set 25 | uwayl
# City not found. Skipping...
# Processing Record 33 of Set 25 | keti bandar
# Processing Record 34 of Set 25 | tatsuno
# Processing Record 35 of Set 25 | gayeri
# Processing Record 36 of Set 25 | ihosy
# Processing Record 37 of Set 25 | khani
# Processing Record 38 of Set 25 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 25 | belmonte
# Processing Record 40 of Set 25 | raudeberg
# Processing Record 41 of Set 25 | guerrero negro
# Processing Record 42 of Set 25 | lagoa
# Processing Record 43 of Set 25 | westport
# Processing Record 44 of Set 25 | moron
# Processing Record 45 of Set 25 | semirom
# Processing Record 46 of Set 25 | hirara
# Processing Record 47 of Set 25 | ahipara
# Processing Record 48 of Set 25 | rio gallegos
# Processing Record 49 of Set 25 | russell
# Processing Record 50 of Set 25 | oranjemund
# Processing Record 1 of Set 26 | sembe
# Processing Record 2 of Set 26 | nata
# Processing Record 3 of Set 26 | ambulu
# Processing Record 4 of Set 26 | rusape
# Processing Record 5 of Set 26 | siocon
# Processing Record 6 of Set 26 | orichi
# Processing Record 7 of Set 26 | dahanu
# Processing Record 8 of Set 26 | padang
# Processing Record 9 of Set 26 | nador
# Processing Record 10 of Set 26 | sukumo
# Processing Record 11 of Set 26 | harboore
# Processing Record 12 of Set 26 | horsham
# Processing Record 13 of Set 26 | bodmin
# Processing Record 14 of Set 26 | pangnirtung
# Processing Record 15 of Set 26 | salinas
# Processing Record 16 of Set 26 | waingapu
# Processing Record 17 of Set 26 | yashalta
# Processing Record 18 of Set 26 | amalapuram
# Processing Record 19 of Set 26 | comodoro rivadavia
# Processing Record 20 of Set 26 | coos bay
# Processing Record 21 of Set 26 | asosa
# Processing Record 22 of Set 26 | yulara
# Processing Record 23 of Set 26 | harper
# Processing Record 24 of Set 26 | namibe
# Processing Record 25 of Set 26 | asyut
# Processing Record 26 of Set 26 | paray-le-monial
# Processing Record 27 of Set 26 | along
# Processing Record 28 of Set 26 | tacuati
# Processing Record 29 of Set 26 | spearfish
# Processing Record 30 of Set 26 | mount isa
# Processing Record 31 of Set 26 | cikarang
# Processing Record 32 of Set 26 | zyryanka
# Processing Record 33 of Set 26 | den helder
# Processing Record 34 of Set 26 | bodden town
# Processing Record 35 of Set 26 | oktyabrskoye
# Processing Record 36 of Set 26 | patos de minas
# Processing Record 37 of Set 26 | walvis bay
# Processing Record 38 of Set 26 | mount pleasant
# Processing Record 39 of Set 26 | rivera
# Processing Record 40 of Set 26 | manaquiri
# Processing Record 41 of Set 26 | sabha
# Processing Record 42 of Set 26 | miles city
# Processing Record 43 of Set 26 | yanchukan
# City not found. Skipping...
# Processing Record 44 of Set 26 | funadhoo
# Processing Record 45 of Set 26 | luangwa
# Processing Record 46 of Set 26 | les cayes
# Processing Record 47 of Set 26 | sivas
# Processing Record 48 of Set 26 | csakvar
# Processing Record 49 of Set 26 | sao joao da barra
# Processing Record 50 of Set 26 | tsiroanomandidy
# Processing Record 1 of Set 27 | sedelnikovo
# City not found. Skipping...
# Processing Record 2 of Set 27 | mgachi
# Processing Record 3 of Set 27 | port hardy
# Processing Record 4 of Set 27 | lubango
# Processing Record 5 of Set 27 | coxim
# Processing Record 6 of Set 27 | ishigaki
# Processing Record 7 of Set 27 | tallahassee
# Processing Record 8 of Set 27 | kitui
# Processing Record 9 of Set 27 | zarkos
# Processing Record 10 of Set 27 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 27 | peterhead
# Processing Record 12 of Set 27 | diu
# Processing Record 13 of Set 27 | paamiut
# Processing Record 14 of Set 27 | van buren
# Processing Record 15 of Set 27 | kingsville
# Processing Record 16 of Set 27 | ulaanbaatar
# Processing Record 17 of Set 27 | saulkrasti
# Processing Record 18 of Set 27 | dunedin
# Processing Record 19 of Set 27 | matagami
# Processing Record 20 of Set 27 | uravakonda
# Processing Record 21 of Set 27 | garmsar
# Processing Record 22 of Set 27 | karachev
# Processing Record 23 of Set 27 | thinadhoo
# Processing Record 24 of Set 27 | uvinza
# Processing Record 25 of Set 27 | winnemucca
# Processing Record 26 of Set 27 | sur
# Processing Record 27 of Set 27 | saint-francois
# Processing Record 28 of Set 27 | hambantota
# Processing Record 29 of Set 27 | kashin
# Processing Record 30 of Set 27 | longonjo
# Processing Record 31 of Set 27 | illapel
# Processing Record 32 of Set 27 | havelock
# Processing Record 33 of Set 27 | mikhaylovka
# Processing Record 34 of Set 27 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 27 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 27 | stoyba
# City not found. Skipping...
# Processing Record 37 of Set 27 | barbar
# City not found. Skipping...
# Processing Record 38 of Set 27 | chadiza
# Processing Record 39 of Set 27 | boa vista
# Processing Record 40 of Set 27 | vilyuysk
# Processing Record 41 of Set 27 | mehamn
# Processing Record 42 of Set 27 | grajewo
# Processing Record 43 of Set 27 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 27 | vyara
# Processing Record 45 of Set 27 | atyuryevo
# City not found. Skipping...
# Processing Record 46 of Set 27 | morshansk
# Processing Record 47 of Set 27 | san joaquin
# Processing Record 48 of Set 27 | port lincoln
# Processing Record 49 of Set 27 | multan
# Processing Record 50 of Set 27 | morondava
# Processing Record 1 of Set 28 | atambua
# Processing Record 2 of Set 28 | tumbagaan
# Processing Record 3 of Set 28 | sola
# Processing Record 4 of Set 28 | jinchang
# Processing Record 5 of Set 28 | manzanillo
# Processing Record 6 of Set 28 | nakhon thai
# Processing Record 7 of Set 28 | kano
# Processing Record 8 of Set 28 | sao jose da coroa grande
# Processing Record 9 of Set 28 | zunyi
# Processing Record 10 of Set 28 | mabaruma
# Processing Record 11 of Set 28 | mitsamiouli
# Processing Record 12 of Set 28 | chubbuck
# Processing Record 13 of Set 28 | ola
# Processing Record 14 of Set 28 | corpus christi
# Processing Record 15 of Set 28 | chardara
# Processing Record 16 of Set 28 | nicolas de pierola
# Processing Record 17 of Set 28 | ler
# Processing Record 18 of Set 28 | kautokeino
# Processing Record 19 of Set 28 | smithers
# Processing Record 20 of Set 28 | hire
# City not found. Skipping...
# Processing Record 21 of Set 28 | falmouth
# Processing Record 22 of Set 28 | singkawang
# Processing Record 23 of Set 28 | ambon
# Processing Record 24 of Set 28 | sept-iles
# Processing Record 25 of Set 28 | panagjuriste
# City not found. Skipping...
# Processing Record 26 of Set 28 | oborniki
# Processing Record 27 of Set 28 | macamic
# Processing Record 28 of Set 28 | acari
# Processing Record 29 of Set 28 | martin
# Processing Record 30 of Set 28 | chapais
# Processing Record 31 of Set 28 | nyurba
# Processing Record 32 of Set 28 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 28 | mouila
# Processing Record 34 of Set 28 | saint-pierre
# Processing Record 35 of Set 28 | bamboo
# Processing Record 36 of Set 28 | nyirtelek
# Processing Record 37 of Set 28 | bucerias
# Processing Record 38 of Set 28 | lyubim
# Processing Record 39 of Set 28 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 28 | brae
# Processing Record 41 of Set 28 | hami
# Processing Record 42 of Set 28 | bongandanga
# Processing Record 43 of Set 28 | coruripe
# Processing Record 44 of Set 28 | yantzaza
# Processing Record 45 of Set 28 | dasoguz
# Processing Record 46 of Set 28 | msanga
# Processing Record 47 of Set 28 | port macquarie
# Processing Record 48 of Set 28 | aitape
# Processing Record 49 of Set 28 | mazyr
# Processing Record 50 of Set 28 | bac lieu
# Processing Record 1 of Set 29 | nemuro
# Processing Record 2 of Set 29 | lasa
# Processing Record 3 of Set 29 | umm lajj
# Processing Record 4 of Set 29 | launceston
# Processing Record 5 of Set 29 | banawang
# Processing Record 6 of Set 29 | skaerbaek
# Processing Record 7 of Set 29 | poso
# Processing Record 8 of Set 29 | morozovsk
# Processing Record 9 of Set 29 | bathsheba
# Processing Record 10 of Set 29 | izvoru barzii
# Processing Record 11 of Set 29 | kunzell
# Processing Record 12 of Set 29 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 29 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 29 | arman
# Processing Record 15 of Set 29 | gribanovskiy
# Processing Record 16 of Set 29 | norrtalje
# Processing Record 17 of Set 29 | aksu
# Processing Record 18 of Set 29 | ibra
# Processing Record 19 of Set 29 | araguaina
# Processing Record 20 of Set 29 | charters towers
# Processing Record 21 of Set 29 | astoria
# Processing Record 22 of Set 29 | xai-xai
# Processing Record 23 of Set 29 | langsa
# Processing Record 24 of Set 29 | himora
# City not found. Skipping...
# Processing Record 25 of Set 29 | kainantu
# Processing Record 26 of Set 29 | sambava
# Processing Record 27 of Set 29 | tura
# Processing Record 28 of Set 29 | boditi
# Processing Record 29 of Set 29 | poyarkovo
# Processing Record 30 of Set 29 | hachinohe
# Processing Record 31 of Set 29 | gboko
# Processing Record 32 of Set 29 | ballina
# Processing Record 33 of Set 29 | vostok
# Processing Record 34 of Set 29 | salekhard
# Processing Record 35 of Set 29 | sicuani
# Processing Record 36 of Set 29 | vanimo
# Processing Record 37 of Set 29 | yumen
# Processing Record 38 of Set 29 | taft
# Processing Record 39 of Set 29 | vermillion
# Processing Record 40 of Set 29 | sovetskiy
# Processing Record 41 of Set 29 | iqaluit
# Processing Record 42 of Set 29 | riyadh
# Processing Record 43 of Set 29 | fort frances
# Processing Record 44 of Set 29 | berlevag
# Processing Record 45 of Set 29 | khorixas
# Processing Record 46 of Set 29 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 29 | bajil
# Processing Record 48 of Set 29 | thunder bay
# Processing Record 49 of Set 29 | baiyin
# Processing Record 50 of Set 29 | tefe
# Processing Record 1 of Set 30 | hikari
# Processing Record 2 of Set 30 | carmen
# Processing Record 3 of Set 30 | nogliki
# Processing Record 4 of Set 30 | itaituba
# Processing Record 5 of Set 30 | arkhangelsk
# Processing Record 6 of Set 30 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 7 of Set 30 | poum
# Processing Record 8 of Set 30 | wagar
# Processing Record 9 of Set 30 | deputatskiy
# Processing Record 10 of Set 30 | tuy hoa
# Processing Record 11 of Set 30 | selikhino
# Processing Record 12 of Set 30 | puerto escondido
# Processing Record 13 of Set 30 | atkarsk
# Processing Record 14 of Set 30 | tabuk
# Processing Record 15 of Set 30 | praia
# Processing Record 16 of Set 30 | ayios kirikos
# City not found. Skipping...
# Processing Record 17 of Set 30 | shitanjing
# Processing Record 18 of Set 30 | lethem
# Processing Record 19 of Set 30 | tazovskiy
# Processing Record 20 of Set 30 | kampong chhnang
# Processing Record 21 of Set 30 | nuuk
# Processing Record 22 of Set 30 | antofagasta
# Processing Record 23 of Set 30 | la palma
# Processing Record 24 of Set 30 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 30 | urzhum
# Processing Record 26 of Set 30 | quesnel
# Processing Record 27 of Set 30 | general pico
# Processing Record 28 of Set 30 | akcaabat
# Processing Record 29 of Set 30 | los andes
# Processing Record 30 of Set 30 | murzzuschlag
# Processing Record 31 of Set 30 | wageningen
# Processing Record 32 of Set 30 | turangi
# Processing Record 33 of Set 30 | anastacio
# Processing Record 34 of Set 30 | manono
# Processing Record 35 of Set 30 | sorong
# Processing Record 36 of Set 30 | adeje
# Processing Record 37 of Set 30 | gualeguay
# Processing Record 38 of Set 30 | amurzet
# Processing Record 39 of Set 30 | aleksandrov gay
# Processing Record 40 of Set 30 | tomatlan
# Processing Record 41 of Set 30 | porbandar
# Processing Record 42 of Set 30 | micheweni
# Processing Record 43 of Set 30 | alice springs
# Processing Record 44 of Set 30 | road town
# Processing Record 45 of Set 30 | talaya
# Processing Record 46 of Set 30 | denpasar
# Processing Record 47 of Set 30 | salta
# Processing Record 48 of Set 30 | adrar
# Processing Record 49 of Set 30 | palu
# Processing Record 50 of Set 30 | lich
# Processing Record 1 of Set 31 | newport
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
city_data
# Out:
# [{'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 66.99,
#   'Humidity': 77,
#   'Wind Speed': 3.31,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Cordoba',
#   'Lat': -31.41,
#   'Lng': -64.18,
#   'Max Temp': 77,
#   'Humidity': 20,
#   'Wind Speed': 13.87,
#   'Cloudiness': 0,
#   'Country': 'AR'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Wind Speed': 2.24,
#   'Cloudiness': 75,
#   'Country': 'MU'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 70.45,
#   'Humidity': 73,
#   'Wind Speed': 17.43,
#   'Cloudiness': 90,
#   'Country': 'BR'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 28.4,
#   'Humidity': 42,
#   'Wind Speed': 21.92,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'San Policarpo',
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Max Temp': 79.74,
#   'Humidity': 83,
#   'Wind Speed': 6.26,
#   'Cloudiness': 100,
#   'Country': 'PH'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 64,
#   'Humidity': 90,
#   'Wind Speed': 12.71,
#   'Cloudiness': 77,
#   'Country': 'ZA'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Wind Speed': 13.87,
#   'Cloudiness': 20,
#   'Country': 'TO'},
#  {'City': 'Nova Olimpia',
#   'Lat': -14.8,
#   'Lng': -57.29,
#   'Max Temp': 84.06,
#   'Humidity': 45,
#   'Wind Speed': 1.88,
#   'Cloudiness': 42,
#   'Country': 'BR'},
#  {'City': 'Nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 39.16,
#   'Humidity': 84,
#   'Wind Speed': 17.58,
#   'Cloudiness': 100,
#   'Country': 'GL'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Wind Speed': 9.17,
#   'Cloudiness': 75,
#   'Country': 'CL'},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Wind Speed': 8.05,
#   'Cloudiness': 18,
#   'Country': 'AU'},
#  {'City': 'College',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': -13,
#   'Humidity': 75,
#   'Wind Speed': 0.58,
#   'Cloudiness': 20,
#   'Country': 'US'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 77.85,
#   'Humidity': 73,
#   'Wind Speed': 17.76,
#   'Cloudiness': 14,
#   'Country': 'PF'},
#  {'City': 'Alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Wind Speed': 23.04,
#   'Cloudiness': 75,
#   'Country': 'NU'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 73.08,
#   'Humidity': 71,
#   'Wind Speed': 14.67,
#   'Cloudiness': 0,
#   'Country': 'PF'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 57.78,
#   'Humidity': 73,
#   'Wind Speed': 5.91,
#   'Cloudiness': 49,
#   'Country': 'BR'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Wind Speed': 18.34,
#   'Cloudiness': 20,
#   'Country': 'ZA'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 32,
#   'Humidity': 96,
#   'Wind Speed': 44.96,
#   'Cloudiness': 100,
#   'Country': 'GL'},
#  {'City': 'Saint-Louis',
#   'Lat': 16.33,
#   'Lng': -15,
#   'Max Temp': 80.6,
#   'Humidity': 47,
#   'Wind Speed': 7.52,
#   'Cloudiness': 0,
#   'Country': 'SN'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 73.4,
#   'Humidity': 40,
#   'Wind Speed': 19.46,
#   'Cloudiness': 75,
#   'Country': 'AU'},
#  {'City': 'Kirakira',
#   'Lat': -10.45,
#   'Lng': 161.92,
#   'Max Temp': 83.32,
#   'Humidity': 75,
#   'Wind Speed': 9.1,
#   'Cloudiness': 92,
#   'Country': 'SB'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Wind Speed': 2.24,
#   'Cloudiness': 75,
#   'Country': 'MU'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 57.2,
#   'Humidity': 44,
#   'Wind Speed': 20.8,
#   'Cloudiness': 40,
#   'Country': 'AR'},
#  {'City': 'Sokone',
#   'Lat': 13.88,
#   'Lng': -16.37,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Wind Speed': 7.72,
#   'Cloudiness': 0,
#   'Country': 'SN'},
#  {'City': 'Dorado',
#   'Lat': 18.46,
#   'Lng': -66.27,
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Wind Speed': 10.29,
#   'Cloudiness': 75,
#   'Country': 'PR'},
#  {'City': 'Pocoes',
#   'Lat': -14.53,
#   'Lng': -40.37,
#   'Max Temp': 62.51,
#   'Humidity': 95,
#   'Wind Speed': 5.5,
#   'Cloudiness': 98,
#   'Country': 'BR'},
#  {'City': 'San Cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Wind Speed': 5.82,
#   'Cloudiness': 40,
#   'Country': 'VE'},
#  {'City': 'Archidona',
#   'Lat': 37.1,
#   'Lng': -4.39,
#   'Max Temp': 61,
#   'Humidity': 92,
#   'Wind Speed': 3.36,
#   'Cloudiness': 98,
#   'Country': 'ES'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 68.34,
#   'Humidity': 87,
#   'Wind Speed': 5.23,
#   'Cloudiness': 40,
#   'Country': 'ZA'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 50,
#   'Humidity': 81,
#   'Wind Speed': 8.95,
#   'Cloudiness': 40,
#   'Country': 'RU'},
#  {'City': 'Kununurra',
#   'Lat': -15.77,
#   'Lng': 128.73,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Wind Speed': 9.91,
#   'Cloudiness': 10,
#   'Country': 'AU'},
#  {'City': 'Ushumun',
#   'Lat': 52.78,
#   'Lng': 126.53,
#   'Max Temp': 8.11,
#   'Humidity': 91,
#   'Wind Speed': 10.13,
#   'Cloudiness': 14,
#   'Country': 'RU'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 36,
#   'Humidity': 69,
#   'Wind Speed': 5.14,
#   'Cloudiness': 55,
#   'Country': 'US'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 57,
#   'Humidity': 70,
#   'Wind Speed': 14.03,
#   'Cloudiness': 4,
#   'Country': 'AU'},
#  {'City': 'Grindavik',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 41,
#   'Humidity': 86,
#   'Wind Speed': 10.29,
#   'Cloudiness': 75,
#   'Country': 'IS'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 65.12,
#   'Humidity': 92,
#   'Wind Speed': 2.3,
#   'Cloudiness': 13,
#   'Country': 'ZA'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.47,
#   'Max Temp': 5.58,
#   'Humidity': 95,
#   'Wind Speed': 2.91,
#   'Cloudiness': 99,
#   'Country': 'RU'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 81.36,
#   'Humidity': 72,
#   'Wind Speed': 16.98,
#   'Cloudiness': 69,
#   'Country': 'KI'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.23,
#   'Lng': 136.77,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Wind Speed': 6.93,
#   'Cloudiness': 96,
#   'Country': 'AU'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 1.04,
#   'Humidity': 79,
#   'Wind Speed': 4,
#   'Cloudiness': 2,
#   'Country': 'GL'},
#  {'City': 'Bystrice Nad Pernstejnem',
#   'Lat': 49.52,
#   'Lng': 16.26,
#   'Max Temp': 55,
#   'Humidity': 87,
#   'Wind Speed': 11.65,
#   'Cloudiness': 100,
#   'Country': 'CZ'},
#  {'City': 'Sladkovo',
#   'Lat': 55.53,
#   'Lng': 70.34,
#   'Max Temp': 27.41,
#   'Humidity': 93,
#   'Wind Speed': 10.6,
#   'Cloudiness': 44,
#   'Country': 'RU'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 69.01,
#   'Humidity': 91,
#   'Wind Speed': 11.01,
#   'Cloudiness': 89,
#   'Country': 'EC'},
#  {'City': 'Mweka',
#   'Lat': -4.85,
#   'Lng': 21.57,
#   'Max Temp': 69.73,
#   'Humidity': 99,
#   'Wind Speed': 1.12,
#   'Cloudiness': 93,
#   'Country': 'CD'},
#  {'City': 'Kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 64.99,
#   'Humidity': 92,
#   'Wind Speed': 3.49,
#   'Cloudiness': 47,
#   'Country': 'ZA'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 69.64,
#   'Humidity': 57,
#   'Wind Speed': 2.01,
#   'Cloudiness': 66,
#   'Country': 'TL'},
#  {'City': 'Roma',
#   'Lat': 43.21,
#   'Lng': -75.46,
#   'Max Temp': 35.6,
#   'Humidity': 55,
#   'Wind Speed': 8.05,
#   'Cloudiness': 90,
#   'Country': 'US'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': -4.07,
#   'Humidity': 91,
#   'Wind Speed': 2.77,
#   'Cloudiness': 95,
#   'Country': 'RU'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 61.88,
#   'Humidity': 66,
#   'Wind Speed': 10.09,
#   'Cloudiness': 15,
#   'Country': 'PT'},
#  {'City': 'Kurtalan',
#   'Lat': 37.93,
#   'Lng': 41.7,
#   'Max Temp': 59,
#   'Humidity': 72,
#   'Wind Speed': 2.24,
#   'Cloudiness': 40,
#   'Country': 'TR'},
#  {'City': 'Cloquet',
#   'Lat': 46.72,
#   'Lng': -92.46,
#   'Max Temp': 68,
#   'Humidity': 25,
#   'Wind Speed': 4.7,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Yerofey Pavlovich',
#   'Lat': 53.97,
#   'Lng': 121.97,
#   'Max Temp': 14.13,
#   'Humidity': 82,
#   'Wind Speed': 3.2,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 64.99,
#   'Humidity': 62,
#   'Wind Speed': 1.99,
#   'Cloudiness': 0,
#   'Country': 'NZ'},
#  {'City': 'Klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Wind Speed': 31.09,
#   'Cloudiness': 100,
#   'Country': 'FO'},
#  {'City': 'Tripoli',
#   'Lat': 32.88,
#   'Lng': 13.19,
#   'Max Temp': 69.78,
#   'Humidity': 63,
#   'Wind Speed': 7.31,
#   'Cloudiness': 0,
#   'Country': 'LY'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 54.66,
#   'Humidity': 80,
#   'Wind Speed': 3.4,
#   'Cloudiness': 2,
#   'Country': 'CL'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': -0.96,
#   'Humidity': 94,
#   'Wind Speed': 4.56,
#   'Cloudiness': 93,
#   'Country': 'RU'},
#  {'City': 'Victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 71.01,
#   'Humidity': 64,
#   'Wind Speed': 8.99,
#   'Cloudiness': 100,
#   'Country': 'HK'},
#  {'City': 'Abu Dhabi',
#   'Lat': 24.47,
#   'Lng': 54.37,
#   'Max Temp': 77,
#   'Humidity': 69,
#   'Wind Speed': 2.24,
#   'Cloudiness': 0,
#   'Country': 'AE'},
#  {'City': 'Biak',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 78.96,
#   'Humidity': 76,
#   'Wind Speed': 2.77,
#   'Cloudiness': 82,
#   'Country': 'ID'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.28,
#   'Lng': 108.01,
#   'Max Temp': 19.36,
#   'Humidity': 96,
#   'Wind Speed': 8.08,
#   'Cloudiness': 99,
#   'Country': 'RU'},
#  {'City': 'Mogadishu',
#   'Lat': 2.04,
#   'Lng': 45.34,
#   'Max Temp': 78.76,
#   'Humidity': 83,
#   'Wind Speed': 9.55,
#   'Cloudiness': 79,
#   'Country': 'SO'},
#  {'City': 'Boyolangu',
#   'Lat': -8.12,
#   'Lng': 111.89,
#   'Max Temp': 76.62,
#   'Humidity': 81,
#   'Wind Speed': 1.99,
#   'Cloudiness': 100,
#   'Country': 'ID'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Max Temp': -7.6,
#   'Humidity': 83,
#   'Wind Speed': 2.24,
#   'Cloudiness': 40,
#   'Country': 'RU'},
#  {'City': 'Shakawe',
#   'Lat': -18.37,
#   'Lng': 21.85,
#   'Max Temp': 67.78,
#   'Humidity': 81,
#   'Wind Speed': 4.85,
#   'Cloudiness': 100,
#   'Country': 'BW'},
#  {'City': 'Bhinmal',
#   'Lat': 25,
#   'Lng': 72.25,
#   'Max Temp': 68.47,
#   'Humidity': 33,
#   'Wind Speed': 3.47,
#   'Cloudiness': 0,
#   'Country': 'IN'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 18.88,
#   'Humidity': 86,
#   'Wind Speed': 15.26,
#   'Cloudiness': 52,
#   'Country': 'RU'},
#  {'City': 'Gravdal',
#   'Lat': 68.12,
#   'Lng': 13.5,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Wind Speed': 26.4,
#   'Cloudiness': 40,
#   'Country': 'NO'},
#  {'City': 'Gornopravdinsk',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 26.71,
#   'Humidity': 95,
#   'Wind Speed': 10.71,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Wind Speed': 2.24,
#   'Cloudiness': 75,
#   'Country': 'MU'},
#  {'City': 'Shenjiamen',
#   'Lat': 29.96,
#   'Lng': 122.3,
#   'Max Temp': 59.18,
#   'Humidity': 61,
#   'Wind Speed': 14.79,
#   'Cloudiness': 71,
#   'Country': 'CN'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 78.85,
#   'Humidity': 71,
#   'Wind Speed': 7.02,
#   'Cloudiness': 83,
#   'Country': 'CV'},
#  {'City': 'Durazno',
#   'Lat': -33.41,
#   'Lng': -56.5,
#   'Max Temp': 58.62,
#   'Humidity': 85,
#   'Wind Speed': 13.56,
#   'Cloudiness': 10,
#   'Country': 'UY'},
#  {'City': 'Kyabram',
#   'Lat': -36.32,
#   'Lng': 145.05,
#   'Max Temp': 66.99,
#   'Humidity': 54,
#   'Wind Speed': 10.47,
#   'Cloudiness': 79,
#   'Country': 'AU'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Max Temp': 64.99,
#   'Humidity': 62,
#   'Wind Speed': 1.99,
#   'Cloudiness': 0,
#   'Country': 'NZ'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.22,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Wind Speed': 11.41,
#   'Cloudiness': 0,
#   'Country': 'PE'},
#  {'City': 'Aswan',
#   'Lat': 24.09,
#   'Lng': 32.91,
#   'Max Temp': 68.22,
#   'Humidity': 42,
#   'Wind Speed': 12.84,
#   'Cloudiness': 0,
#   'Country': 'EG'},
#  {'City': 'Zinder',
#   'Lat': 13.81,
#   'Lng': 8.99,
#   'Max Temp': 80.29,
#   'Humidity': 17,
#   'Wind Speed': 12.46,
#   'Cloudiness': 61,
#   'Country': 'NE'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 3.99,
#   'Humidity': 91,
#   'Wind Speed': 5.68,
#   'Cloudiness': 0,
#   'Country': 'RU'},
#  {'City': 'Hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 62.6,
#   'Humidity': 36,
#   'Wind Speed': 9.17,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Puksoozero',
#   'Lat': 62.59,
#   'Lng': 40.61,
#   'Max Temp': 45.18,
#   'Humidity': 89,
#   'Wind Speed': 11.63,
#   'Cloudiness': 98,
#   'Country': 'RU'},
#  {'City': 'Chabahar',
#   'Lat': 25.29,
#   'Lng': 60.64,
#   'Max Temp': 73.54,
#   'Humidity': 64,
#   'Wind Speed': 3.98,
#   'Cloudiness': 0,
#   'Country': 'IR'},
#  {'City': 'Ban Nahin',
#   'Lat': 18.24,
#   'Lng': 104.21,
#   'Max Temp': 65.44,
#   'Humidity': 77,
#   'Wind Speed': 3.76,
#   'Cloudiness': 4,
#   'Country': 'LA'},
#  {'City': 'Usinsk',
#   'Lat': 65.99,
#   'Lng': 57.53,
#   'Max Temp': 37.89,
#   'Humidity': 93,
#   'Wind Speed': 22.91,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Max Temp': 82.18,
#   'Humidity': 73,
#   'Wind Speed': 5.5,
#   'Cloudiness': 0,
#   'Country': 'IN'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 82.4,
#   'Humidity': 20,
#   'Wind Speed': 2.8,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 73.4,
#   'Humidity': 40,
#   'Wind Speed': 19.46,
#   'Cloudiness': 75,
#   'Country': 'AU'},
#  {'City': 'Sandakan',
#   'Lat': 5.84,
#   'Lng': 118.12,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Wind Speed': 4.03,
#   'Cloudiness': 20,
#   'Country': 'MY'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 30.2,
#   'Humidity': 74,
#   'Wind Speed': 14.99,
#   'Cloudiness': 90,
#   'Country': 'SJ'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 5,
#   'Humidity': 71,
#   'Wind Speed': 11.41,
#   'Cloudiness': 20,
#   'Country': 'CA'},
#  {'City': 'Aguimes',
#   'Lat': 27.91,
#   'Lng': -15.45,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Wind Speed': 20.8,
#   'Cloudiness': 40,
#   'Country': 'ES'},
#  {'City': 'Rawson',
#   'Lat': -43.3,
#   'Lng': -65.1,
#   'Max Temp': 63.72,
#   'Humidity': 59,
#   'Wind Speed': 15.37,
#   'Cloudiness': 58,
#   'Country': 'AR'},
#  {'City': 'Hofn',
#   'Lat': 64.25,
#   'Lng': -15.21,
#   'Max Temp': 41.99,
#   'Humidity': 63,
#   'Wind Speed': 8.59,
#   'Cloudiness': 25,
#   'Country': 'IS'},
#  {'City': 'Zhanakorgan',
#   'Lat': 43.91,
#   'Lng': 67.25,
#   'Max Temp': 46.22,
#   'Humidity': 49,
#   'Wind Speed': 10.02,
#   'Cloudiness': 0,
#   'Country': 'KZ'},
#  {'City': 'Whyalla',
#   'Lat': -33.03,
#   'Lng': 137.58,
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Wind Speed': 17.22,
#   'Cloudiness': 90,
#   'Country': 'AU'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Wind Speed': 5.82,
#   'Cloudiness': 75,
#   'Country': 'ZA'},
#  {'City': 'Cozumel',
#   'Lat': 20.51,
#   'Lng': -86.95,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Wind Speed': 13.87,
#   'Cloudiness': 90,
#   'Country': 'MX'},
#  {'City': 'Nome',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 26.6,
#   'Humidity': 68,
#   'Wind Speed': 11.41,
#   'Cloudiness': 90,
#   'Country': 'US'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': -16.38,
#   'Humidity': 83,
#   'Wind Speed': 4.88,
#   'Cloudiness': 0,
#   'Country': 'RU'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Wind Speed': 6.93,
#   'Cloudiness': 75,
#   'Country': 'US'},
#  {'City': 'Luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 58.71,
#   'Humidity': 91,
#   'Wind Speed': 4.27,
#   'Cloudiness': 2,
#   'Country': 'NA'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 82.65,
#   'Humidity': 72,
#   'Wind Speed': 6.78,
#   'Cloudiness': 99,
#   'Country': 'MV'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 10.4,
#   'Humidity': 72,
#   'Wind Speed': 13.87,
#   'Cloudiness': 90,
#   'Country': 'US'},
#  {'City': 'Ouadda',
#   'Lat': 8.08,
#   'Lng': 22.4,
#   'Max Temp': 70.61,
#   'Humidity': 60,
#   'Wind Speed': 2.3,
#   'Cloudiness': 34,
#   'Country': 'CF'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 82.4,
#   'Humidity': 78,
#   'Wind Speed': 13.87,
#   'Cloudiness': 40,
#   'Country': 'US'},
#  {'City': 'Labuan',
#   'Lat': 5.28,
#   'Lng': 115.24,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Wind Speed': 7.81,
#   'Cloudiness': 20,
#   'Country': 'MY'},
#  {'City': 'Yar-Sale',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 25.38,
#   'Humidity': 98,
#   'Wind Speed': 10.25,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 66.2,
#   'Humidity': 88,
#   'Wind Speed': 8.23,
#   'Cloudiness': 98,
#   'Country': 'ZA'},
#  {'City': 'Artyom',
#   'Lat': 40.47,
#   'Lng': 50.33,
#   'Max Temp': 55.4,
#   'Humidity': 93,
#   'Wind Speed': 2.24,
#   'Cloudiness': 100,
#   'Country': 'AZ'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 10.11,
#   'Humidity': 96,
#   'Wind Speed': 3.83,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Wind Speed': 13.87,
#   'Cloudiness': 0,
#   'Country': 'AU'},
#  {'City': 'Ruston',
#   'Lat': 32.52,
#   'Lng': -92.64,
#   'Max Temp': 68,
#   'Humidity': 42,
#   'Wind Speed': 3.36,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Barranca',
#   'Lat': -10.75,
#   'Lng': -77.77,
#   'Max Temp': 63.48,
#   'Humidity': 81,
#   'Wind Speed': 7.23,
#   'Cloudiness': 89,
#   'Country': 'PE'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 55.4,
#   'Humidity': 93,
#   'Wind Speed': 18.34,
#   'Cloudiness': 90,
#   'Country': 'AU'},
#  {'City': 'Vozhega',
#   'Lat': 60.47,
#   'Lng': 40.22,
#   'Max Temp': 43.38,
#   'Humidity': 93,
#   'Wind Speed': 9.51,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Brownsville',
#   'Lat': 25.9,
#   'Lng': -97.5,
#   'Max Temp': 78.8,
#   'Humidity': 44,
#   'Wind Speed': 11.41,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 64.99,
#   'Humidity': 62,
#   'Wind Speed': 1.99,
#   'Cloudiness': 4,
#   'Country': 'NZ'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 69.8,
#   'Humidity': 60,
#   'Wind Speed': 5.82,
#   'Cloudiness': 0,
#   'Country': 'RE'},
#  {'City': 'Miraflores',
#   'Lat': 19.22,
#   'Lng': -98.81,
#   'Max Temp': 71.6,
#   'Humidity': 35,
#   'Wind Speed': 4.7,
#   'Cloudiness': 5,
#   'Country': 'MX'},
#  {'City': 'Ilulissat',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 37.4,
#   'Humidity': 69,
#   'Wind Speed': 14.99,
#   'Cloudiness': 100,
#   'Country': 'GL'},
#  {'City': 'Betioky',
#   'Lat': -23.72,
#   'Lng': 44.38,
#   'Max Temp': 70.47,
#   'Humidity': 83,
#   'Wind Speed': 2.1,
#   'Cloudiness': 15,
#   'Country': 'MG'},
#  {'City': 'Codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 57.9,
#   'Humidity': 92,
#   'Wind Speed': 15.08,
#   'Cloudiness': 100,
#   'Country': 'AU'},
#  {'City': 'Shingu',
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Max Temp': 49.01,
#   'Humidity': 63,
#   'Wind Speed': 6.2,
#   'Cloudiness': 0,
#   'Country': 'JP'},
#  {'City': 'Mandali',
#   'Lat': 33.75,
#   'Lng': 45.55,
#   'Max Temp': 71.92,
#   'Humidity': 25,
#   'Wind Speed': 3.96,
#   'Cloudiness': 82,
#   'Country': 'IQ'},
#  {'City': 'Lata',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 55.99,
#   'Humidity': 84,
#   'Wind Speed': 4.83,
#   'Cloudiness': 0,
#   'Country': 'PT'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 51.01,
#   'Humidity': 81,
#   'Wind Speed': 1.99,
#   'Cloudiness': 3,
#   'Country': 'GB'},
#  {'City': 'Erenhot',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 33.08,
#   'Humidity': 74,
#   'Wind Speed': 11.39,
#   'Cloudiness': 5,
#   'Country': 'CN'},
#  {'City': 'Araouane',
#   'Lat': 18.9,
#   'Lng': -3.53,
#   'Max Temp': 83.32,
#   'Humidity': 15,
#   'Wind Speed': 9.37,
#   'Cloudiness': 100,
#   'Country': 'ML'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 12.2,
#   'Humidity': 85,
#   'Wind Speed': 9.17,
#   'Cloudiness': 90,
#   'Country': 'CA'},
#  {'City': 'San Andres',
#   'Lat': 12.58,
#   'Lng': -81.7,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Wind Speed': 31.79,
#   'Cloudiness': 40,
#   'Country': 'CO'},
#  {'City': 'Verkhnevilyuysk',
#   'Lat': 63.45,
#   'Lng': 120.32,
#   'Max Temp': 8.19,
#   'Humidity': 96,
#   'Wind Speed': 3.42,
#   'Cloudiness': 99,
#   'Country': 'RU'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 61,
#   'Humidity': 87,
#   'Wind Speed': 16.11,
#   'Cloudiness': 0,
#   'Country': 'AR'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 39.2,
#   'Humidity': 69,
#   'Wind Speed': 34.45,
#   'Cloudiness': 0,
#   'Country': 'NO'},
#  {'City': 'Ardakan',
#   'Lat': 32.31,
#   'Lng': 54.02,
#   'Max Temp': 57.2,
#   'Humidity': 20,
#   'Wind Speed': 4.7,
#   'Cloudiness': 0,
#   'Country': 'IR'},
#  {'City': 'Pecos',
#   'Lat': 31.42,
#   'Lng': -103.49,
#   'Max Temp': 80.6,
#   'Humidity': 18,
#   'Wind Speed': 5.82,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Chenghai',
#   'Lat': 23.46,
#   'Lng': 116.77,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Wind Speed': 4.47,
#   'Cloudiness': 0,
#   'Country': 'CN'},
#  {'City': 'Asau',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 46,
#   'Humidity': 98,
#   'Wind Speed': 2.21,
#   'Cloudiness': 100,
#   'Country': 'RO'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 42.8,
#   'Humidity': 41,
#   'Wind Speed': 6.93,
#   'Cloudiness': 13,
#   'Country': 'UZ'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Wind Speed': 10.29,
#   'Cloudiness': 5,
#   'Country': 'MX'},
#  {'City': 'Okitipupa',
#   'Lat': 6.5,
#   'Lng': 4.78,
#   'Max Temp': 75.96,
#   'Humidity': 95,
#   'Wind Speed': 1.23,
#   'Cloudiness': 100,
#   'Country': 'NG'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 1.02,
#   'Humidity': 92,
#   'Wind Speed': 10.07,
#   'Cloudiness': 12,
#   'Country': 'RU'},
#  {'City': 'Bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.28,
#   'Max Temp': 77.72,
#   'Humidity': 77,
#   'Wind Speed': 1.83,
#   'Cloudiness': 97,
#   'Country': 'ID'},
#  {'City': 'Yuxia',
#   'Lat': 34.06,
#   'Lng': 108.63,
#   'Max Temp': 52,
#   'Humidity': 93,
#   'Wind Speed': 2.24,
#   'Cloudiness': 81,
#   'Country': 'CN'},
#  {'City': 'Sobolevo',
#   'Lat': 54.43,
#   'Lng': 31.9,
#   'Max Temp': 44.51,
#   'Humidity': 86,
#   'Wind Speed': 8.16,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 23,
#   'Humidity': 92,
#   'Wind Speed': 2.24,
#   'Cloudiness': 90,
#   'Country': 'CA'},
#  {'City': 'Ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 57,
#   'Humidity': 76,
#   'Wind Speed': 18.34,
#   'Cloudiness': 61,
#   'Country': 'CL'},
#  {'City': 'Cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 62.33,
#   'Humidity': 78,
#   'Wind Speed': 12.01,
#   'Cloudiness': 3,
#   'Country': 'BR'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 56.01,
#   'Humidity': 86,
#   'Wind Speed': 7.43,
#   'Cloudiness': 0,
#   'Country': 'UY'},
#  {'City': 'Celestun',
#   'Lat': 20.87,
#   'Lng': -90.4,
#   'Max Temp': 77.5,
#   'Humidity': 74,
#   'Wind Speed': 16.42,
#   'Cloudiness': 42,
#   'Country': 'MX'},
#  {'City': 'Nizhniy Tsasuchey',
#   'Lat': 50.52,
#   'Lng': 115.13,
#   'Max Temp': 20.5,
#   'Humidity': 94,
#   'Wind Speed': 7.31,
#   'Cloudiness': 69,
#   'Country': 'RU'},
#  {'City': 'Leningradskiy',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 6.98,
#   'Humidity': 86,
#   'Wind Speed': 17.76,
#   'Cloudiness': 7,
#   'Country': 'RU'},
#  {'City': 'Kralendijk',
#   'Lat': 12.15,
#   'Lng': -68.27,
#   'Max Temp': 83.12,
#   'Humidity': 78,
#   'Wind Speed': 20.87,
#   'Cloudiness': 74,
#   'Country': 'BQ'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.78,
#   'Max Temp': 68,
#   'Humidity': 86,
#   'Wind Speed': 8.99,
#   'Cloudiness': 100,
#   'Country': 'NZ'},
#  {'City': 'Praia Da Vitoria',
#   'Lat': 38.73,
#   'Lng': -27.07,
#   'Max Temp': 61,
#   'Humidity': 77,
#   'Wind Speed': 17.76,
#   'Cloudiness': 75,
#   'Country': 'PT'},
#  {'City': 'Cedar City',
#   'Lat': 37.68,
#   'Lng': -113.06,
#   'Max Temp': 73.4,
#   'Humidity': 17,
#   'Wind Speed': 13.87,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Max Temp': 73.4,
#   'Humidity': 43,
#   'Wind Speed': 4.7,
#   'Cloudiness': 0,
#   'Country': 'OM'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Wind Speed': 3.36,
#   'Cloudiness': 20,
#   'Country': 'MY'},
#  {'City': 'Naze',
#   'Lat': 28.37,
#   'Lng': 129.48,
#   'Max Temp': 66.2,
#   'Humidity': 63,
#   'Wind Speed': 21.92,
#   'Cloudiness': 75,
#   'Country': 'JP'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -7.2,
#   'Humidity': 85,
#   'Wind Speed': 2.93,
#   'Cloudiness': 0,
#   'Country': 'RU'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.02,
#   'Lng': -93.22,
#   'Max Temp': 75.2,
#   'Humidity': 25,
#   'Wind Speed': 8.05,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 78.42,
#   'Humidity': 87,
#   'Wind Speed': 1.5,
#   'Cloudiness': 100,
#   'Country': 'PH'},
#  {'City': 'Narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 37.4,
#   'Humidity': 92,
#   'Wind Speed': 3.36,
#   'Cloudiness': 100,
#   'Country': 'GL'},
#  {'City': 'Meulaboh',
#   'Lat': 4.14,
#   'Lng': 96.13,
#   'Max Temp': 75.52,
#   'Humidity': 93,
#   'Wind Speed': 7.49,
#   'Cloudiness': 100,
#   'Country': 'ID'},
#  {'City': 'Vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 74.25,
#   'Humidity': 89,
#   'Wind Speed': 10.11,
#   'Cloudiness': 100,
#   'Country': 'NC'},
#  {'City': 'Tiarei',
#   'Lat': -17.53,
#   'Lng': -149.33,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Wind Speed': 19.46,
#   'Cloudiness': 75,
#   'Country': 'PF'},
#  {'City': 'Mudgee',
#   'Lat': -32.59,
#   'Lng': 149.59,
#   'Max Temp': 66.99,
#   'Humidity': 72,
#   'Wind Speed': 1.12,
#   'Cloudiness': 9,
#   'Country': 'AU'},
#  {'City': 'Tobermory',
#   'Lat': 45.25,
#   'Lng': -81.67,
#   'Max Temp': 39.2,
#   'Humidity': 81,
#   'Wind Speed': 6.93,
#   'Cloudiness': 94,
#   'Country': 'CA'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 66.2,
#   'Humidity': 72,
#   'Wind Speed': 19.46,
#   'Cloudiness': 75,
#   'Country': 'PT'},
#  {'City': 'Zhicheng',
#   'Lat': 30.3,
#   'Lng': 111.5,
#   'Max Temp': 55,
#   'Humidity': 70,
#   'Wind Speed': 1.79,
#   'Cloudiness': 96,
#   'Country': 'CN'},
#  {'City': 'Axim',
#   'Lat': 4.87,
#   'Lng': -2.24,
#   'Max Temp': 78.37,
#   'Humidity': 86,
#   'Wind Speed': 5.68,
#   'Cloudiness': 70,
#   'Country': 'GH'},
#  {'City': 'Bonavista',
#   'Lat': 48.65,
#   'Lng': -53.11,
#   'Max Temp': 37.99,
#   'Humidity': 80,
#   'Wind Speed': 4.7,
#   'Cloudiness': 96,
#   'Country': 'CA'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 18.84,
#   'Humidity': 92,
#   'Wind Speed': 7.11,
#   'Cloudiness': 100,
#   'Country': 'GL'},
#  {'City': 'Faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Max Temp': 79.25,
#   'Humidity': 82,
#   'Wind Speed': 20.96,
#   'Cloudiness': 96,
#   'Country': 'PF'},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.98,
#   'Lng': 57.61,
#   'Max Temp': 69.01,
#   'Humidity': 73,
#   'Wind Speed': 1.99,
#   'Cloudiness': 41,
#   'Country': 'MU'},
#  {'City': 'Gubkinskiy',
#   'Lat': 64.43,
#   'Lng': 76.5,
#   'Max Temp': 23.07,
#   'Humidity': 98,
#   'Wind Speed': 8.81,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Grajau',
#   'Lat': -5.82,
#   'Lng': -46.14,
#   'Max Temp': 73.69,
#   'Humidity': 95,
#   'Wind Speed': 4.43,
#   'Cloudiness': 100,
#   'Country': 'BR'},
#  {'City': 'Semarang',
#   'Lat': -6.99,
#   'Lng': 110.42,
#   'Max Temp': 77.16,
#   'Humidity': 81,
#   'Wind Speed': 6.15,
#   'Cloudiness': 100,
#   'Country': 'ID'},
#  {'City': 'Manturovo',
#   'Lat': 58.34,
#   'Lng': 44.76,
#   'Max Temp': 36.5,
#   'Humidity': 96,
#   'Wind Speed': 7.63,
#   'Cloudiness': 22,
#   'Country': 'RU'},
#  {'City': 'Kiruna',
#   'Lat': 67.86,
#   'Lng': 20.23,
#   'Max Temp': 32,
#   'Humidity': 95,
#   'Wind Speed': 11.41,
#   'Cloudiness': 73,
#   'Country': 'SE'},
#  {'City': 'Swinoujscie',
#   'Lat': 53.91,
#   'Lng': 14.25,
#   'Max Temp': 50,
#   'Humidity': 88,
#   'Wind Speed': 14.81,
#   'Cloudiness': 98,
#   'Country': 'PL'},
#  {'City': 'Mangrol',
#   'Lat': 21.12,
#   'Lng': 70.12,
#   'Max Temp': 78.1,
#   'Humidity': 43,
#   'Wind Speed': 8.28,
#   'Cloudiness': 0,
#   'Country': 'IN'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Max Temp': 1.4,
#   'Humidity': 84,
#   'Wind Speed': 2.24,
#   'Cloudiness': 75,
#   'Country': 'CA'},
#  {'City': 'Calabozo',
#   'Lat': 8.92,
#   'Lng': -67.43,
#   'Max Temp': 76.8,
#   'Humidity': 88,
#   'Wind Speed': 4.85,
#   'Cloudiness': 9,
#   'Country': 'VE'},
#  {'City': 'Aranos',
#   'Lat': -24.13,
#   'Lng': 19.12,
#   'Max Temp': 71.51,
#   'Humidity': 42,
#   'Wind Speed': 10.92,
#   'Cloudiness': 48,
#   'Country': 'NA'},
#  {'City': 'Ninh Binh',
#   'Lat': 20.25,
#   'Lng': 105.97,
#   'Max Temp': 66.9,
#   'Humidity': 68,
#   'Wind Speed': 6.44,
#   'Cloudiness': 100,
#   'Country': 'VN'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 61,
#   'Humidity': 74,
#   'Wind Speed': 5.99,
#   'Cloudiness': 0,
#   'Country': 'NZ'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 74.62,
#   'Humidity': 86,
#   'Wind Speed': 3.31,
#   'Cloudiness': 80,
#   'Country': 'ID'},
#  {'City': 'Mezen',
#   'Lat': 65.85,
#   'Lng': 44.24,
#   'Max Temp': 44.87,
#   'Humidity': 86,
#   'Wind Speed': 11.68,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Jurmala',
#   'Lat': 56.97,
#   'Lng': 23.77,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Wind Speed': 6.93,
#   'Cloudiness': 0,
#   'Country': 'LV'},
#  {'City': 'Sompeta',
#   'Lat': 18.93,
#   'Lng': 84.6,
#   'Max Temp': 77.76,
#   'Humidity': 77,
#   'Wind Speed': 6.35,
#   'Cloudiness': 50,
#   'Country': 'IN'},
#  {'City': 'Faya',
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 60.8,
#   'Humidity': 87,
#   'Wind Speed': 4.7,
#   'Cloudiness': 0,
#   'Country': 'SA'},
#  {'City': 'Stromness',
#   'Lat': 58.97,
#   'Lng': -3.3,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Wind Speed': 13.87,
#   'Cloudiness': 95,
#   'Country': 'GB'},
#  {'City': 'Ossora',
#   'Lat': 59.24,
#   'Lng': 163.07,
#   'Max Temp': 41.2,
#   'Humidity': 90,
#   'Wind Speed': 31.56,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Trelew',
#   'Lat': -43.25,
#   'Lng': -65.31,
#   'Max Temp': 64.89,
#   'Humidity': 51,
#   'Wind Speed': 20.22,
#   'Cloudiness': 59,
#   'Country': 'AR'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 41,
#   'Humidity': 80,
#   'Wind Speed': 8.05,
#   'Cloudiness': 75,
#   'Country': 'CA'},
#  {'City': 'Canaries',
#   'Lat': 28,
#   'Lng': -15.5,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Wind Speed': 20.8,
#   'Cloudiness': 40,
#   'Country': 'ES'},
#  {'City': 'Manta',
#   'Lat': -0.95,
#   'Lng': -80.73,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Wind Speed': 13.87,
#   'Cloudiness': 40,
#   'Country': 'EC'},
#  {'City': 'Avanigadda',
#   'Lat': 16.02,
#   'Lng': 80.92,
#   'Max Temp': 74.77,
#   'Humidity': 90,
#   'Wind Speed': 4.65,
#   'Cloudiness': 62,
#   'Country': 'IN'},
#  {'City': 'Hanzhong',
#   'Lat': 33.07,
#   'Lng': 107.03,
#   'Max Temp': 51.73,
#   'Humidity': 64,
#   'Wind Speed': 1.43,
#   'Cloudiness': 97,
#   'Country': 'CN'},
#  {'City': 'Barcelos',
#   'Lat': 41.54,
#   'Lng': -8.62,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Wind Speed': 10.29,
#   'Cloudiness': 0,
#   'Country': 'PT'},
#  {'City': 'Shakhtinsk',
#   'Lat': 49.71,
#   'Lng': 72.59,
#   'Max Temp': 24.8,
#   'Humidity': 73,
#   'Wind Speed': 6.71,
#   'Cloudiness': 90,
#   'Country': 'KZ'},
#  {'City': 'Carballo',
#   'Lat': 43.21,
#   'Lng': -8.69,
#   'Max Temp': 50,
#   'Humidity': 85,
#   'Wind Speed': 4.18,
#   'Cloudiness': 41,
#   'Country': 'ES'},
#  {'City': 'Linares',
#   'Lat': -35.85,
#   'Lng': -71.6,
#   'Max Temp': 69.39,
#   'Humidity': 54,
#   'Wind Speed': 8.25,
#   'Cloudiness': 0,
#   'Country': 'CL'},
#  {'City': 'Alta Floresta',
#   'Lat': -9.88,
#   'Lng': -56.09,
#   'Max Temp': 79,
#   'Humidity': 68,
#   'Wind Speed': 2.44,
#   'Cloudiness': 87,
#   'Country': 'BR'},
#  {'City': 'Canutama',
#   'Lat': -6.53,
#   'Lng': -64.38,
#   'Max Temp': 78.17,
#   'Humidity': 85,
#   'Wind Speed': 6.13,
#   'Cloudiness': 40,
#   'Country': 'BR'},
#  {'City': 'Portland',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Max Temp': 57.99,
#   'Humidity': 93,
#   'Wind Speed': 9.17,
#   'Cloudiness': 90,
#   'Country': 'US'},
#  {'City': 'Te Anau',
#   'Lat': -45.42,
#   'Lng': 167.72,
#   'Max Temp': 66.45,
#   'Humidity': 57,
#   'Wind Speed': 5.35,
#   'Cloudiness': 11,
#   'Country': 'NZ'},
#  {'City': 'Fallon',
#   'Lat': 39.47,
#   'Lng': -118.78,
#   'Max Temp': 75.99,
#   'Humidity': 12,
#   'Wind Speed': 5.82,
#   'Cloudiness': 40,
#   'Country': 'US'},
#  {'City': 'Payo',
#   'Lat': -3.75,
#   'Lng': 103.64,
#   'Max Temp': 71.22,
#   'Humidity': 91,
#   'Wind Speed': 1.9,
#   'Cloudiness': 77,
#   'Country': 'ID'},
#  {'City': 'Hualmay',
#   'Lat': -11.1,
#   'Lng': -77.61,
#   'Max Temp': 64.67,
#   'Humidity': 77,
#   'Wind Speed': 7.81,
#   'Cloudiness': 68,
#   'Country': 'PE'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 69.01,
#   'Humidity': 73,
#   'Wind Speed': 1.99,
#   'Cloudiness': 58,
#   'Country': 'MU'},
#  {'City': 'Springdale',
#   'Lat': 36.19,
#   'Lng': -94.13,
#   'Max Temp': 73.4,
#   'Humidity': 28,
#   'Wind Speed': 10.29,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Heilbron',
#   'Lat': -27.28,
#   'Lng': 27.97,
#   'Max Temp': 61.43,
#   'Humidity': 65,
#   'Wind Speed': 2.57,
#   'Cloudiness': 53,
#   'Country': 'ZA'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 46.4,
#   'Humidity': 65,
#   'Wind Speed': 3.36,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Haverfordwest',
#   'Lat': 51.8,
#   'Lng': -4.97,
#   'Max Temp': 46,
#   'Humidity': 93,
#   'Wind Speed': 4.7,
#   'Cloudiness': 31,
#   'Country': 'GB'},
#  {'City': 'Buala',
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 84.38,
#   'Humidity': 72,
#   'Wind Speed': 6.2,
#   'Cloudiness': 59,
#   'Country': 'SB'},
#  {'City': 'Salym',
#   'Lat': 60.06,
#   'Lng': 71.48,
#   'Max Temp': 27.39,
#   'Humidity': 95,
#   'Wind Speed': 12.19,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5,
#   'Lng': -13.86,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Wind Speed': 19.46,
#   'Cloudiness': 75,
#   'Country': 'ES'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.73,
#   'Lng': -25.67,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Wind Speed': 13.87,
#   'Cloudiness': 75,
#   'Country': 'PT'},
#  {'City': 'Tabas',
#   'Lat': 33.6,
#   'Lng': 56.92,
#   'Max Temp': 59,
#   'Humidity': 19,
#   'Wind Speed': 2.24,
#   'Cloudiness': 0,
#   'Country': 'IR'},
#  {'City': 'Lompoc',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Wind Speed': 14.99,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Tolaga Bay',
#   'Lat': -38.37,
#   'Lng': 178.3,
#   'Max Temp': 70.99,
#   'Humidity': 55,
#   'Wind Speed': 14.2,
#   'Cloudiness': 96,
#   'Country': 'NZ'},
#  {'City': 'Khandbari',
#   'Lat': 27.37,
#   'Lng': 87.2,
#   'Max Temp': 61.43,
#   'Humidity': 59,
#   'Wind Speed': 4.16,
#   'Cloudiness': 13,
#   'Country': 'NP'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Wind Speed': 10.29,
#   'Cloudiness': 96,
#   'Country': 'CK'},
#  {'City': 'Shagonar',
#   'Lat': 51.53,
#   'Lng': 92.8,
#   'Max Temp': 30.52,
#   'Humidity': 97,
#   'Wind Speed': 4.09,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 42.8,
#   'Humidity': 48,
#   'Wind Speed': 4.7,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Raghunathpur',
#   'Lat': 23.55,
#   'Lng': 86.67,
#   'Max Temp': 68.07,
#   'Humidity': 40,
#   'Wind Speed': 5.93,
#   'Cloudiness': 0,
#   'Country': 'IN'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 73.06,
#   'Humidity': 72,
#   'Wind Speed': 24.81,
#   'Cloudiness': 20,
#   'Country': 'BS'},
#  {'City': 'Tual',
#   'Lat': -5.67,
#   'Lng': 132.75,
#   'Max Temp': 81.37,
#   'Humidity': 78,
#   'Wind Speed': 13.82,
#   'Cloudiness': 97,
#   'Country': 'ID'},
#  {'City': 'Hobyo',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 80.33,
#   'Humidity': 82,
#   'Wind Speed': 10.65,
#   'Cloudiness': 93,
#   'Country': 'SO'},
#  {'City': 'Cayenne',
#   'Lat': 4.93,
#   'Lng': -52.33,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Wind Speed': 3.36,
#   'Cloudiness': 0,
#   'Country': 'GF'},
#  {'City': 'Las Vegas',
#   'Lat': 36.17,
#   'Lng': -115.14,
#   'Max Temp': 86,
#   'Humidity': 17,
#   'Wind Speed': 5.82,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Tazmalt',
#   'Lat': 36.39,
#   'Lng': 4.4,
#   'Max Temp': 59,
#   'Humidity': 77,
#   'Wind Speed': 4.7,
#   'Cloudiness': 40,
#   'Country': 'DZ'},
#  {'City': 'Roald',
#   'Lat': 62.58,
#   'Lng': 6.13,
#   'Max Temp': 46.99,
#   'Humidity': 75,
#   'Wind Speed': 19.46,
#   'Cloudiness': 64,
#   'Country': 'NO'},
#  {'City': 'Camopi',
#   'Lat': 3.17,
#   'Lng': -52.32,
#   'Max Temp': 75.31,
#   'Humidity': 95,
#   'Wind Speed': 3.13,
#   'Cloudiness': 100,
#   'Country': 'GF'},
#  {'City': 'Juneau',
#   'Lat': 58.3,
#   'Lng': -134.42,
#   'Max Temp': 30.2,
#   'Humidity': 86,
#   'Wind Speed': 4.7,
#   'Cloudiness': 90,
#   'Country': 'US'},
#  {'City': 'Slave Lake',
#   'Lat': 55.28,
#   'Lng': -114.77,
#   'Max Temp': 50,
#   'Humidity': 57,
#   'Wind Speed': 0.87,
#   'Cloudiness': 75,
#   'Country': 'CA'},
#  {'City': 'Mercedes',
#   'Lat': -34.65,
#   'Lng': -59.43,
#   'Max Temp': 68,
#   'Humidity': 74,
#   'Wind Speed': 3,
#   'Cloudiness': 25,
#   'Country': 'AR'},
#  {'City': 'Kashi',
#   'Lat': 39.45,
#   'Lng': 75.98,
#   'Max Temp': 41,
#   'Humidity': 38,
#   'Wind Speed': 11.18,
#   'Cloudiness': 0,
#   'Country': 'CN'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 16.3,
#   'Humidity': 88,
#   'Wind Speed': 9.17,
#   'Cloudiness': 0,
#   'Country': 'RU'},
#  {'City': 'Ketchikan',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 44.6,
#   'Humidity': 75,
#   'Wind Speed': 9.17,
#   'Cloudiness': 20,
#   'Country': 'US'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 70.54,
#   'Humidity': 82,
#   'Wind Speed': 4.5,
#   'Cloudiness': 94,
#   'Country': 'MG'},
#  {'City': 'Alekseyevka',
#   'Lat': 50.63,
#   'Lng': 38.69,
#   'Max Temp': 46.45,
#   'Humidity': 90,
#   'Wind Speed': 3.65,
#   'Cloudiness': 3,
#   'Country': 'RU'},
#  {'City': 'San Patricio',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Max Temp': 73.4,
#   'Humidity': 56,
#   'Wind Speed': 14.99,
#   'Cloudiness': 20,
#   'Country': 'US'},
#  {'City': 'Kamiiso',
#   'Lat': 41.82,
#   'Lng': 140.65,
#   'Max Temp': 39.2,
#   'Humidity': 81,
#   'Wind Speed': 20.8,
#   'Cloudiness': 75,
#   'Country': 'JP'},
#  {'City': 'Victor Harbor',
#   'Lat': -35.57,
#   'Lng': 138.62,
#   'Max Temp': 57.99,
#   'Humidity': 88,
#   'Wind Speed': 1.99,
#   'Cloudiness': 100,
#   'Country': 'AU'},
#  {'City': 'Anda',
#   'Lat': 46.4,
#   'Lng': 125.32,
#   'Max Temp': 21.51,
#   'Humidity': 78,
#   'Wind Speed': 11.34,
#   'Cloudiness': 0,
#   'Country': 'CN'},
#  {'City': 'Rio Grande',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Max Temp': 61,
#   'Humidity': 74,
#   'Wind Speed': 4,
#   'Cloudiness': 0,
#   'Country': 'BR'},
#  {'City': 'Pochutla',
#   'Lat': 15.74,
#   'Lng': -96.47,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Wind Speed': 11.41,
#   'Cloudiness': 20,
#   'Country': 'MX'},
#  {'City': 'Zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': -0.51,
#   'Humidity': 90,
#   'Wind Speed': 2.17,
#   'Cloudiness': 91,
#   'Country': 'RU'},
#  {'City': 'Altay',
#   'Lat': 47.87,
#   'Lng': 88.12,
#   'Max Temp': 31.28,
#   'Humidity': 85,
#   'Wind Speed': 3.11,
#   'Cloudiness': 100,
#   'Country': 'CN'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.76,
#   'Max Temp': 66,
#   'Humidity': 85,
#   'Wind Speed': 5.77,
#   'Cloudiness': 16,
#   'Country': 'IL'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Lat': -0.41,
#   'Lng': -65.02,
#   'Max Temp': 77.23,
#   'Humidity': 91,
#   'Wind Speed': 2.06,
#   'Cloudiness': 100,
#   'Country': 'BR'},
#  {'City': 'Valdivia',
#   'Lat': -39.81,
#   'Lng': -73.25,
#   'Max Temp': 55.4,
#   'Humidity': 82,
#   'Wind Speed': 3.36,
#   'Cloudiness': 20,
#   'Country': 'CL'},
#  {'City': 'Bay Roberts',
#   'Lat': 47.6,
#   'Lng': -53.26,
#   'Max Temp': 39.2,
#   'Humidity': 80,
#   'Wind Speed': 8.05,
#   'Cloudiness': 75,
#   'Country': 'CA'},
#  {'City': 'Mamlyutka',
#   'Lat': 54.94,
#   'Lng': 68.54,
#   'Max Temp': 27.84,
#   'Humidity': 94,
#   'Wind Speed': 10.45,
#   'Cloudiness': 8,
#   'Country': 'KZ'},
#  {'City': 'Laguna',
#   'Lat': 38.42,
#   'Lng': -121.42,
#   'Max Temp': 80.01,
#   'Humidity': 33,
#   'Wind Speed': 3.36,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Bafra',
#   'Lat': 41.57,
#   'Lng': 35.91,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Wind Speed': 1.12,
#   'Cloudiness': 75,
#   'Country': 'TR'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.23,
#   'Lng': -58.65,
#   'Max Temp': 25.59,
#   'Humidity': 81,
#   'Wind Speed': 12.01,
#   'Cloudiness': 65,
#   'Country': 'CA'},
#  {'City': 'High Level',
#   'Lat': 58.52,
#   'Lng': -117.14,
#   'Max Temp': 17.6,
#   'Humidity': 85,
#   'Wind Speed': 8.05,
#   'Cloudiness': 90,
#   'Country': 'CA'},
#  {'City': 'Pyaozerskiy',
#   'Lat': 65.83,
#   'Lng': 31.17,
#   'Max Temp': 40.69,
#   'Humidity': 82,
#   'Wind Speed': 12.06,
#   'Cloudiness': 95,
#   'Country': 'RU'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 50,
#   'Humidity': 66,
#   'Wind Speed': 8.05,
#   'Cloudiness': 20,
#   'Country': 'JP'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 84.7,
#   'Humidity': 74,
#   'Wind Speed': 7.81,
#   'Cloudiness': 100,
#   'Country': 'PG'},
#  {'City': 'Dutse',
#   'Lat': 11.76,
#   'Lng': 9.34,
#   'Max Temp': 76.23,
#   'Humidity': 30,
#   'Wind Speed': 6.67,
#   'Cloudiness': 2,
#   'Country': 'NG'},
#  {'City': 'Pietarsaari',
#   'Lat': 63.65,
#   'Lng': 22.68,
#   'Max Temp': 39.99,
#   'Humidity': 93,
#   'Wind Speed': 9.17,
#   'Cloudiness': 0,
#   'Country': 'FI'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Wind Speed': 17.22,
#   'Cloudiness': 40,
#   'Country': 'ES'},
#  {'City': 'Jumla',
#   'Lat': 29.27,
#   'Lng': 82.18,
#   'Max Temp': 40.26,
#   'Humidity': 62,
#   'Wind Speed': 4.79,
#   'Cloudiness': 0,
#   'Country': 'NP'},
#  {'City': 'Flinders',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 73,
#   'Humidity': 63,
#   'Wind Speed': 1.01,
#   'Cloudiness': 18,
#   'Country': 'AU'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 55.4,
#   'Humidity': 93,
#   'Wind Speed': 5.82,
#   'Cloudiness': 40,
#   'Country': 'AU'},
#  {'City': 'Knysna',
#   'Lat': -34.04,
#   'Lng': 23.05,
#   'Max Temp': 64.4,
#   'Humidity': 100,
#   'Wind Speed': 3.36,
#   'Cloudiness': 84,
#   'Country': 'ZA'},
#  {'City': 'Haines Junction',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 1.4,
#   'Humidity': 70,
#   'Wind Speed': 2.24,
#   'Cloudiness': 100,
#   'Country': 'CA'},
#  {'City': 'Stornoway',
#   'Lat': 58.21,
#   'Lng': -6.39,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Wind Speed': 11.41,
#   'Cloudiness': 60,
#   'Country': 'GB'},
#  {'City': 'Sulya',
#   'Lat': 12.57,
#   'Lng': 75.38,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Wind Speed': 2.17,
#   'Cloudiness': 75,
#   'Country': 'IN'},
#  {'City': 'Ortigueira',
#   'Lat': -24.21,
#   'Lng': -50.95,
#   'Max Temp': 63.68,
#   'Humidity': 56,
#   'Wind Speed': 0.49,
#   'Cloudiness': 64,
#   'Country': 'BR'},
#  {'City': 'Monroe',
#   'Lat': 43.15,
#   'Lng': -77.68,
#   'Max Temp': 39.99,
#   'Humidity': 69,
#   'Wind Speed': 4.7,
#   'Cloudiness': 90,
#   'Country': 'US'},
#  {'City': 'La Ronge',
#   'Lat': 55.1,
#   'Lng': -105.28,
#   'Max Temp': 46.4,
#   'Humidity': 65,
#   'Wind Speed': 3.44,
#   'Cloudiness': 98,
#   'Country': 'CA'},
#  {'City': 'Muros',
#   'Lat': 42.78,
#   'Lng': -9.06,
#   'Max Temp': 44.01,
#   'Humidity': 91,
#   'Wind Speed': 11.59,
#   'Cloudiness': 25,
#   'Country': 'ES'},
#  {'City': 'Sibolga',
#   'Lat': 1.74,
#   'Lng': 98.78,
#   'Max Temp': 74.28,
#   'Humidity': 86,
#   'Wind Speed': 3.62,
#   'Cloudiness': 100,
#   'Country': 'ID'},
#  {'City': 'Tornio',
#   'Lat': 65.85,
#   'Lng': 24.15,
#   'Max Temp': 39.2,
#   'Humidity': 86,
#   'Wind Speed': 6.93,
#   'Cloudiness': 100,
#   'Country': 'FI'},
#  {'City': 'Porto Novo',
#   'Lat': 6.5,
#   'Lng': 2.6,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Wind Speed': 10.29,
#   'Cloudiness': 20,
#   'Country': 'BJ'},
#  {'City': 'Elizabeth City',
#   'Lat': 36.29,
#   'Lng': -76.25,
#   'Max Temp': 57.2,
#   'Humidity': 44,
#   'Wind Speed': 4.7,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Zabaykalsk',
#   'Lat': 49.63,
#   'Lng': 117.32,
#   'Max Temp': 18.27,
#   'Humidity': 91,
#   'Wind Speed': 6.55,
#   'Cloudiness': 58,
#   'Country': 'RU'},
#  {'City': 'Saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Max Temp': 59,
#   'Humidity': 93,
#   'Wind Speed': 3.36,
#   'Cloudiness': 19,
#   'Country': 'ZA'},
#  {'City': 'Teguldet',
#   'Lat': 57.31,
#   'Lng': 88.17,
#   'Max Temp': 27.32,
#   'Humidity': 97,
#   'Wind Speed': 6.53,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Gizo',
#   'Lat': -8.1,
#   'Lng': 156.84,
#   'Max Temp': 84.92,
#   'Humidity': 71,
#   'Wind Speed': 9.93,
#   'Cloudiness': 94,
#   'Country': 'SB'},
#  {'City': 'Scarborough',
#   'Lat': 54.28,
#   'Lng': -0.4,
#   'Max Temp': 41,
#   'Humidity': 81,
#   'Wind Speed': 1.99,
#   'Cloudiness': 75,
#   'Country': 'GB'},
#  {'City': 'Kapit',
#   'Lat': 2.02,
#   'Lng': 112.93,
#   'Max Temp': 74.28,
#   'Humidity': 94,
#   'Wind Speed': 1.28,
#   'Cloudiness': 86,
#   'Country': 'MY'},
#  {'City': 'Broome',
#   'Lat': 42.25,
#   'Lng': -75.83,
#   'Max Temp': 37,
#   'Humidity': 74,
#   'Wind Speed': 4.7,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Mountain Home',
#   'Lat': 43.13,
#   'Lng': -115.69,
#   'Max Temp': 66.2,
#   'Humidity': 19,
#   'Wind Speed': 3.36,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Max Temp': 43.45,
#   'Humidity': 75,
#   'Wind Speed': 12.55,
#   'Cloudiness': 100,
#   'Country': 'IS'},
#  {'City': 'Minab',
#   'Lat': 27.15,
#   'Lng': 57.08,
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Wind Speed': 6.93,
#   'Cloudiness': 0,
#   'Country': 'IR'},
#  {'City': 'Takoradi',
#   'Lat': 4.88,
#   'Lng': -1.76,
#   'Max Temp': 79.05,
#   'Humidity': 85,
#   'Wind Speed': 6.89,
#   'Cloudiness': 35,
#   'Country': 'GH'},
#  {'City': 'Vila',
#   'Lat': 42.03,
#   'Lng': -8.16,
#   'Max Temp': 44.01,
#   'Humidity': 81,
#   'Wind Speed': 11.99,
#   'Cloudiness': 11,
#   'Country': 'PT'},
#  {'City': 'Rodez',
#   'Lat': 44.5,
#   'Lng': 2.58,
#   'Max Temp': 46.99,
#   'Humidity': 93,
#   'Wind Speed': 11.41,
#   'Cloudiness': 90,
#   'Country': 'FR'},
#  {'City': 'Phonhong',
#   'Lat': 18.5,
#   'Lng': 102.42,
#   'Max Temp': 70.59,
#   'Humidity': 89,
#   'Wind Speed': 1.45,
#   'Cloudiness': 72,
#   'Country': 'LA'},
#  {'City': 'Ivankiv',
#   'Lat': 50.94,
#   'Lng': 29.89,
#   'Max Temp': 44.6,
#   'Humidity': 100,
#   'Wind Speed': 2.24,
#   'Cloudiness': 78,
#   'Country': 'UA'},
#  {'City': 'Kostomuksha',
#   'Lat': 64.57,
#   'Lng': 30.58,
#   'Max Temp': 41.02,
#   'Humidity': 81,
#   'Wind Speed': 12.5,
#   'Cloudiness': 91,
#   'Country': 'RU'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 83.32,
#   'Humidity': 78,
#   'Wind Speed': 9.84,
#   'Cloudiness': 87,
#   'Country': 'PW'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 37.26,
#   'Humidity': 86,
#   'Wind Speed': 11.54,
#   'Cloudiness': 11,
#   'Country': 'RU'},
#  {'City': 'Eureka',
#   'Lat': 40.8,
#   'Lng': -124.16,
#   'Max Temp': 68,
#   'Humidity': 78,
#   'Wind Speed': 3,
#   'Cloudiness': 17,
#   'Country': 'US'},
#  {'City': 'Curvelo',
#   'Lat': -18.76,
#   'Lng': -44.43,
#   'Max Temp': 67.55,
#   'Humidity': 85,
#   'Wind Speed': 6.08,
#   'Cloudiness': 22,
#   'Country': 'BR'},
#  {'City': 'Lokosovo',
#   'Lat': 61.13,
#   'Lng': 74.82,
#   'Max Temp': 26.6,
#   'Humidity': 97,
#   'Wind Speed': 12.08,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Muravlenko',
#   'Lat': 63.79,
#   'Lng': 74.52,
#   'Max Temp': 23.7,
#   'Humidity': 98,
#   'Wind Speed': 12.73,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 55.4,
#   'Humidity': 54,
#   'Wind Speed': 13.87,
#   'Cloudiness': 20,
#   'Country': 'JP'},
#  {'City': 'Teya',
#   'Lat': 60.38,
#   'Lng': 92.63,
#   'Max Temp': 16.72,
#   'Humidity': 94,
#   'Wind Speed': 4.88,
#   'Cloudiness': 93,
#   'Country': 'RU'},
#  {'City': 'Bintulu',
#   'Lat': 3.17,
#   'Lng': 113.03,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Wind Speed': 3.36,
#   'Cloudiness': 20,
#   'Country': 'MY'},
#  {'City': 'Alyangula',
#   'Lat': -13.85,
#   'Lng': 136.42,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Wind Speed': 5.57,
#   'Cloudiness': 40,
#   'Country': 'AU'},
#  {'City': 'Mazamet',
#   'Lat': 43.49,
#   'Lng': 2.37,
#   'Max Temp': 51.8,
#   'Humidity': 100,
#   'Wind Speed': 6.93,
#   'Cloudiness': 90,
#   'Country': 'FR'},
#  {'City': 'Toora-Khem',
#   'Lat': 52.47,
# ...
#   'Humidity': 78,
#   'Wind Speed': 2.8,
#   'Cloudiness': 16,
#   'Country': 'CN'},
#  {'City': 'Bongandanga',
#   'Lat': 1.5,
#   'Lng': 21.05,
#   'Max Temp': 72.27,
#   'Humidity': 97,
#   'Wind Speed': 0.69,
#   'Cloudiness': 96,
#   'Country': 'CD'},
#  {'City': 'Coruripe',
#   'Lat': -10.13,
#   'Lng': -36.18,
#   'Max Temp': 78.04,
#   'Humidity': 82,
#   'Wind Speed': 11.92,
#   'Cloudiness': 96,
#   'Country': 'BR'},
#  {'City': 'Yantzaza',
#   'Lat': -3.83,
#   'Lng': -78.76,
#   'Max Temp': 72.5,
#   'Humidity': 80,
#   'Wind Speed': 0.74,
#   'Cloudiness': 62,
#   'Country': 'EC'},
#  {'City': 'Dasoguz',
#   'Lat': 41.84,
#   'Lng': 59.97,
#   'Max Temp': 48.2,
#   'Humidity': 31,
#   'Wind Speed': 11.41,
#   'Cloudiness': 0,
#   'Country': 'TM'},
#  {'City': 'Msanga',
#   'Lat': -6.05,
#   'Lng': 36.03,
#   'Max Temp': 65.93,
#   'Humidity': 81,
#   'Wind Speed': 7.67,
#   'Cloudiness': 39,
#   'Country': 'TZ'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.43,
#   'Lng': 152.92,
#   'Max Temp': 73,
#   'Humidity': 55,
#   'Wind Speed': 1.01,
#   'Cloudiness': 0,
#   'Country': 'AU'},
#  {'City': 'Aitape',
#   'Lat': -3.14,
#   'Lng': 142.35,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Wind Speed': 4.65,
#   'Cloudiness': 100,
#   'Country': 'PG'},
#  {'City': 'Mazyr',
#   'Lat': 52.05,
#   'Lng': 29.25,
#   'Max Temp': 40.5,
#   'Humidity': 94,
#   'Wind Speed': 5.23,
#   'Cloudiness': 0,
#   'Country': 'BY'},
#  {'City': 'Bac Lieu',
#   'Lat': 9.29,
#   'Lng': 105.72,
#   'Max Temp': 77.72,
#   'Humidity': 88,
#   'Wind Speed': 3.78,
#   'Cloudiness': 45,
#   'Country': 'VN'},
#  {'City': 'Nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 41.58,
#   'Humidity': 67,
#   'Wind Speed': 22.62,
#   'Cloudiness': 61,
#   'Country': 'JP'},
#  {'City': 'Lasa',
#   'Lat': 46.62,
#   'Lng': 10.7,
#   'Max Temp': 51.01,
#   'Humidity': 93,
#   'Wind Speed': 2.24,
#   'Cloudiness': 75,
#   'Country': 'IT'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.02,
#   'Lng': 37.27,
#   'Max Temp': 78.01,
#   'Humidity': 56,
#   'Wind Speed': 9.1,
#   'Cloudiness': 0,
#   'Country': 'SA'},
#  {'City': 'Launceston',
#   'Lat': -41.45,
#   'Lng': 147.17,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Wind Speed': 18.34,
#   'Cloudiness': 75,
#   'Country': 'AU'},
#  {'City': 'Banawang',
#   'Lat': 14.61,
#   'Lng': 120.39,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Wind Speed': 2.24,
#   'Cloudiness': 75,
#   'Country': 'PH'},
#  {'City': 'Skaerbaek',
#   'Lat': 55.16,
#   'Lng': 8.77,
#   'Max Temp': 48.2,
#   'Humidity': 76,
#   'Wind Speed': 33.33,
#   'Cloudiness': 72,
#   'Country': 'DK'},
#  {'City': 'Poso',
#   'Lat': -1.4,
#   'Lng': 120.75,
#   'Max Temp': 81,
#   'Humidity': 68,
#   'Wind Speed': 3.42,
#   'Cloudiness': 60,
#   'Country': 'ID'},
#  {'City': 'Morozovsk',
#   'Lat': 48.35,
#   'Lng': 41.83,
#   'Max Temp': 48.56,
#   'Humidity': 87,
#   'Wind Speed': 4.61,
#   'Cloudiness': 14,
#   'Country': 'RU'},
#  {'City': 'Bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Wind Speed': 17.22,
#   'Cloudiness': 20,
#   'Country': 'BB'},
#  {'City': 'Izvoru Barzii',
#   'Lat': 44.71,
#   'Lng': 22.67,
#   'Max Temp': 57.56,
#   'Humidity': 81,
#   'Wind Speed': 3.02,
#   'Cloudiness': 99,
#   'Country': 'RO'},
#  {'City': 'Kunzell',
#   'Lat': 50.54,
#   'Lng': 9.72,
#   'Max Temp': 46.99,
#   'Humidity': 92,
#   'Wind Speed': 1.01,
#   'Cloudiness': 97,
#   'Country': 'DE'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.17,
#   'Max Temp': 34.52,
#   'Humidity': 91,
#   'Wind Speed': 25.39,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Gribanovskiy',
#   'Lat': 51.46,
#   'Lng': 41.98,
#   'Max Temp': 43.61,
#   'Humidity': 90,
#   'Wind Speed': 2.75,
#   'Cloudiness': 1,
#   'Country': 'RU'},
#  {'City': 'Norrtalje',
#   'Lat': 59.76,
#   'Lng': 18.7,
#   'Max Temp': 48,
#   'Humidity': 85,
#   'Wind Speed': 14,
#   'Cloudiness': 0,
#   'Country': 'SE'},
#  {'City': 'Aksu',
#   'Lat': 41.12,
#   'Lng': 80.26,
#   'Max Temp': 36.82,
#   'Humidity': 71,
#   'Wind Speed': 1.01,
#   'Cloudiness': 0,
#   'Country': 'CN'},
#  {'City': 'Ibra',
#   'Lat': 22.69,
#   'Lng': 58.53,
#   'Max Temp': 58.57,
#   'Humidity': 53,
#   'Wind Speed': 3.42,
#   'Cloudiness': 0,
#   'Country': 'OM'},
#  {'City': 'Araguaina',
#   'Lat': -7.19,
#   'Lng': -48.21,
#   'Max Temp': 75.4,
#   'Humidity': 87,
#   'Wind Speed': 4.63,
#   'Cloudiness': 100,
#   'Country': 'BR'},
#  {'City': 'Charters Towers',
#   'Lat': -20.1,
#   'Lng': 146.27,
#   'Max Temp': 77.99,
#   'Humidity': 51,
#   'Wind Speed': 9.71,
#   'Cloudiness': 38,
#   'Country': 'AU'},
#  {'City': 'Astoria',
#   'Lat': 46.19,
#   'Lng': -123.83,
#   'Max Temp': 57.99,
#   'Humidity': 93,
#   'Wind Speed': 18.34,
#   'Cloudiness': 90,
#   'Country': 'US'},
#  {'City': 'Xai-Xai',
#   'Lat': -25.05,
#   'Lng': 33.64,
#   'Max Temp': 72.03,
#   'Humidity': 71,
#   'Wind Speed': 9.08,
#   'Cloudiness': 8,
#   'Country': 'MZ'},
#  {'City': 'Langsa',
#   'Lat': 4.47,
#   'Lng': 97.97,
#   'Max Temp': 73.38,
#   'Humidity': 96,
#   'Wind Speed': 3.09,
#   'Cloudiness': 100,
#   'Country': 'ID'},
#  {'City': 'Kainantu',
#   'Lat': -6.29,
#   'Lng': 145.87,
#   'Max Temp': 70.63,
#   'Humidity': 76,
#   'Wind Speed': 0.6,
#   'Cloudiness': 97,
#   'Country': 'PG'},
#  {'City': 'Sambava',
#   'Lat': -14.27,
#   'Lng': 50.17,
#   'Max Temp': 72.55,
#   'Humidity': 84,
#   'Wind Speed': 11.41,
#   'Cloudiness': 93,
#   'Country': 'MG'},
#  {'City': 'Tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 64.94,
#   'Humidity': 72,
#   'Wind Speed': 0.58,
#   'Cloudiness': 0,
#   'Country': 'IN'},
#  {'City': 'Boditi',
#   'Lat': 6.97,
#   'Lng': 37.87,
#   'Max Temp': 54.03,
#   'Humidity': 42,
#   'Wind Speed': 5.08,
#   'Cloudiness': 14,
#   'Country': 'ET'},
#  {'City': 'Poyarkovo',
#   'Lat': 49.6,
#   'Lng': 128.68,
#   'Max Temp': 15.26,
#   'Humidity': 92,
#   'Wind Speed': 8.61,
#   'Cloudiness': 0,
#   'Country': 'RU'},
#  {'City': 'Hachinohe',
#   'Lat': 40.5,
#   'Lng': 141.5,
#   'Max Temp': 39.2,
#   'Humidity': 66,
#   'Wind Speed': 16.11,
#   'Cloudiness': 75,
#   'Country': 'JP'},
#  {'City': 'Gboko',
#   'Lat': 7.32,
#   'Lng': 9,
#   'Max Temp': 79.45,
#   'Humidity': 63,
#   'Wind Speed': 6.33,
#   'Cloudiness': 100,
#   'Country': 'NG'},
#  {'City': 'Ballina',
#   'Lat': -28.87,
#   'Lng': 153.57,
#   'Max Temp': 73,
#   'Humidity': 60,
#   'Wind Speed': 11.41,
#   'Cloudiness': 40,
#   'Country': 'AU'},
#  {'City': 'Vostok',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 11.55,
#   'Humidity': 91,
#   'Wind Speed': 11.43,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Salekhard',
#   'Lat': 66.53,
#   'Lng': 66.6,
#   'Max Temp': 27.39,
#   'Humidity': 98,
#   'Wind Speed': 7.29,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Sicuani',
#   'Lat': -14.27,
#   'Lng': -71.23,
#   'Max Temp': 55.9,
#   'Humidity': 54,
#   'Wind Speed': 5.77,
#   'Cloudiness': 99,
#   'Country': 'PE'},
#  {'City': 'Vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 82.45,
#   'Humidity': 76,
#   'Wind Speed': 7.16,
#   'Cloudiness': 100,
#   'Country': 'PG'},
#  {'City': 'Yumen',
#   'Lat': 40.28,
#   'Lng': 97.2,
#   'Max Temp': 34.97,
#   'Humidity': 69,
#   'Wind Speed': 10.45,
#   'Cloudiness': 29,
#   'Country': 'CN'},
#  {'City': 'Taft',
#   'Lat': 31.75,
#   'Lng': 54.21,
#   'Max Temp': 57.2,
#   'Humidity': 20,
#   'Wind Speed': 4.7,
#   'Cloudiness': 0,
#   'Country': 'IR'},
#  {'City': 'Vermillion',
#   'Lat': 42.78,
#   'Lng': -96.93,
#   'Max Temp': 80.6,
#   'Humidity': 22,
#   'Wind Speed': 3.36,
#   'Cloudiness': 1,
#   'Country': 'US'},
#  {'City': 'Sovetskiy',
#   'Lat': 61.36,
#   'Lng': 63.58,
#   'Max Temp': 35.11,
#   'Humidity': 84,
#   'Wind Speed': 12.77,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 14,
#   'Humidity': 78,
#   'Wind Speed': 13.87,
#   'Cloudiness': 75,
#   'Country': 'CA'},
#  {'City': 'Riyadh',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 64.4,
#   'Humidity': 39,
#   'Wind Speed': 4.79,
#   'Cloudiness': 0,
#   'Country': 'SA'},
#  {'City': 'Fort Frances',
#   'Lat': 48.6,
#   'Lng': -93.4,
#   'Max Temp': 68,
#   'Humidity': 24,
#   'Wind Speed': 5.82,
#   'Cloudiness': 1,
#   'Country': 'CA'},
#  {'City': 'Berlevag',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 42.8,
#   'Humidity': 70,
#   'Wind Speed': 20.8,
#   'Cloudiness': 40,
#   'Country': 'NO'},
#  {'City': 'Khorixas',
#   'Lat': -20.37,
#   'Lng': 14.97,
#   'Max Temp': 65.79,
#   'Humidity': 37,
#   'Wind Speed': 7.47,
#   'Cloudiness': 38,
#   'Country': 'NA'},
#  {'City': 'Bajil',
#   'Lat': 15.06,
#   'Lng': 43.29,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Wind Speed': 3.71,
#   'Cloudiness': 0,
#   'Country': 'YE'},
#  {'City': 'Thunder Bay',
#   'Lat': 48.4,
#   'Lng': -89.32,
#   'Max Temp': 46.4,
#   'Humidity': 70,
#   'Wind Speed': 9.17,
#   'Cloudiness': 20,
#   'Country': 'CA'},
#  {'City': 'Baiyin',
#   'Lat': 36.56,
#   'Lng': 104.21,
#   'Max Temp': 42.01,
#   'Humidity': 63,
#   'Wind Speed': 8.95,
#   'Cloudiness': 0,
#   'Country': 'CN'},
#  {'City': 'Tefe',
#   'Lat': -3.35,
#   'Lng': -64.71,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Wind Speed': 2.24,
#   'Cloudiness': 40,
#   'Country': 'BR'},
#  {'City': 'Hikari',
#   'Lat': 33.95,
#   'Lng': 131.95,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Wind Speed': 5.82,
#   'Cloudiness': 20,
#   'Country': 'JP'},
#  {'City': 'Carmen',
#   'Lat': 18.63,
#   'Lng': -91.83,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Wind Speed': 18.34,
#   'Cloudiness': 75,
#   'Country': 'MX'},
#  {'City': 'Nogliki',
#   'Lat': 51.83,
#   'Lng': 143.17,
#   'Max Temp': 25.79,
#   'Humidity': 90,
#   'Wind Speed': 14.67,
#   'Cloudiness': 81,
#   'Country': 'RU'},
#  {'City': 'Itaituba',
#   'Lat': -4.28,
#   'Lng': -55.98,
#   'Max Temp': 79.77,
#   'Humidity': 79,
#   'Wind Speed': 3.89,
#   'Cloudiness': 94,
#   'Country': 'BR'},
#  {'City': 'Arkhangelsk',
#   'Lat': 64.54,
#   'Lng': 40.54,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Wind Speed': 11.18,
#   'Cloudiness': 90,
#   'Country': 'RU'},
#  {'City': 'Poum',
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Max Temp': 77.41,
#   'Humidity': 78,
#   'Wind Speed': 7.11,
#   'Cloudiness': 100,
#   'Country': 'NC'},
#  {'City': 'Wagar',
#   'Lat': 16.15,
#   'Lng': 36.2,
#   'Max Temp': 77.85,
#   'Humidity': 62,
#   'Wind Speed': 14.65,
#   'Cloudiness': 0,
#   'Country': 'SD'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': -13.72,
#   'Humidity': 86,
#   'Wind Speed': 1.3,
#   'Cloudiness': 0,
#   'Country': 'RU'},
#  {'City': 'Tuy Hoa',
#   'Lat': 13.08,
#   'Lng': 109.3,
#   'Max Temp': 74.44,
#   'Humidity': 87,
#   'Wind Speed': 7.31,
#   'Cloudiness': 100,
#   'Country': 'VN'},
#  {'City': 'Selikhino',
#   'Lat': 50.37,
#   'Lng': 137.5,
#   'Max Temp': 24.78,
#   'Humidity': 89,
#   'Wind Speed': 12.77,
#   'Cloudiness': 99,
#   'Country': 'RU'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.07,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Wind Speed': 8.05,
#   'Cloudiness': 20,
#   'Country': 'MX'},
#  {'City': 'Atkarsk',
#   'Lat': 51.87,
#   'Lng': 45.01,
#   'Max Temp': 45.68,
#   'Humidity': 72,
#   'Wind Speed': 6.62,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Tabuk',
#   'Lat': 17.42,
#   'Lng': 121.44,
#   'Max Temp': 73.31,
#   'Humidity': 89,
#   'Wind Speed': 6.46,
#   'Cloudiness': 95,
#   'Country': 'PH'},
#  {'City': 'Praia',
#   'Lat': 14.92,
#   'Lng': -23.51,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Wind Speed': 13.87,
#   'Cloudiness': 0,
#   'Country': 'CV'},
#  {'City': 'Shitanjing',
#   'Lat': 39.23,
#   'Lng': 106.34,
#   'Max Temp': 39.88,
#   'Humidity': 57,
#   'Wind Speed': 9.17,
#   'Cloudiness': 0,
#   'Country': 'CN'},
#  {'City': 'Lethem',
#   'Lat': 3.38,
#   'Lng': -59.8,
#   'Max Temp': 83.16,
#   'Humidity': 65,
#   'Wind Speed': 6.42,
#   'Cloudiness': 56,
#   'Country': 'GY'},
#  {'City': 'Tazovskiy',
#   'Lat': 67.47,
#   'Lng': 78.7,
#   'Max Temp': 9.34,
#   'Humidity': 96,
#   'Wind Speed': 4.59,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Kampong Chhnang',
#   'Lat': 12.17,
#   'Lng': 104.55,
#   'Max Temp': 73.96,
#   'Humidity': 84,
#   'Wind Speed': 1.88,
#   'Cloudiness': 56,
#   'Country': 'KH'},
#  {'City': 'Nuuk',
#   'Lat': 64.18,
#   'Lng': -51.72,
#   'Max Temp': 33.8,
#   'Humidity': 93,
#   'Wind Speed': 57.49,
#   'Cloudiness': 99,
#   'Country': 'GL'},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Wind Speed': 14.99,
#   'Cloudiness': 75,
#   'Country': 'CL'},
#  {'City': 'La Palma',
#   'Lat': 33.85,
#   'Lng': -118.05,
#   'Max Temp': 80.6,
#   'Humidity': 36,
#   'Wind Speed': 4.7,
#   'Cloudiness': 40,
#   'Country': 'US'},
#  {'City': 'Urzhum',
#   'Lat': 57.11,
#   'Lng': 50,
#   'Max Temp': 32.38,
#   'Humidity': 95,
#   'Wind Speed': 7.43,
#   'Cloudiness': 12,
#   'Country': 'RU'},
#  {'City': 'Quesnel',
#   'Lat': 53,
#   'Lng': -122.5,
#   'Max Temp': 48.2,
#   'Humidity': 76,
#   'Wind Speed': 9.17,
#   'Cloudiness': 90,
#   'Country': 'CA'},
#  {'City': 'General Pico',
#   'Lat': -35.66,
#   'Lng': -63.76,
#   'Max Temp': 73.49,
#   'Humidity': 46,
#   'Wind Speed': 12.12,
#   'Cloudiness': 19,
#   'Country': 'AR'},
#  {'City': 'Akcaabat',
#   'Lat': 41.02,
#   'Lng': 39.57,
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Wind Speed': 4.7,
#   'Cloudiness': 75,
#   'Country': 'TR'},
#  {'City': 'Los Andes',
#   'Lat': -32.83,
#   'Lng': -70.6,
#   'Max Temp': 82.4,
#   'Humidity': 20,
#   'Wind Speed': 16.11,
#   'Cloudiness': 0,
#   'Country': 'CL'},
#  {'City': 'Murzzuschlag',
#   'Lat': 47.6,
#   'Lng': 15.68,
#   'Max Temp': 59,
#   'Humidity': 62,
#   'Wind Speed': 1.01,
#   'Cloudiness': 100,
#   'Country': 'AT'},
#  {'City': 'Wageningen',
#   'Lat': 51.97,
#   'Lng': 5.67,
#   'Max Temp': 46,
#   'Humidity': 93,
#   'Wind Speed': 10.29,
#   'Cloudiness': 8,
#   'Country': 'NL'},
#  {'City': 'Turangi',
#   'Lat': -39,
#   'Lng': 175.93,
#   'Max Temp': 60.35,
#   'Humidity': 75,
#   'Wind Speed': 2.84,
#   'Cloudiness': 100,
#   'Country': 'NZ'},
#  {'City': 'Anastacio',
#   'Lat': -20.48,
#   'Lng': -55.81,
#   'Max Temp': 77.11,
#   'Humidity': 45,
#   'Wind Speed': 3.33,
#   'Cloudiness': 27,
#   'Country': 'BR'},
#  {'City': 'Manono',
#   'Lat': -7.3,
#   'Lng': 27.42,
#   'Max Temp': 71.91,
#   'Humidity': 83,
#   'Wind Speed': 0.96,
#   'Cloudiness': 98,
#   'Country': 'CD'},
#  {'City': 'Sorong',
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 79.63,
#   'Humidity': 82,
#   'Wind Speed': 9.15,
#   'Cloudiness': 100,
#   'Country': 'ID'},
#  {'City': 'Adeje',
#   'Lat': 28.12,
#   'Lng': -16.73,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Wind Speed': 24.16,
#   'Cloudiness': 20,
#   'Country': 'ES'},
#  {'City': 'Gualeguay',
#   'Lat': -33.14,
#   'Lng': -59.31,
#   'Max Temp': 63.28,
#   'Humidity': 76,
#   'Wind Speed': 8.55,
#   'Cloudiness': 1,
#   'Country': 'AR'},
#  {'City': 'Amurzet',
#   'Lat': 47.7,
#   'Lng': 131.1,
#   'Max Temp': 22.42,
#   'Humidity': 79,
#   'Wind Speed': 11.3,
#   'Cloudiness': 62,
#   'Country': 'RU'},
#  {'City': 'Aleksandrov Gay',
#   'Lat': 50.15,
#   'Lng': 48.57,
#   'Max Temp': 48.7,
#   'Humidity': 50,
#   'Wind Speed': 9.24,
#   'Cloudiness': 99,
#   'Country': 'RU'},
#  {'City': 'Tomatlan',
#   'Lat': 19.93,
#   'Lng': -105.25,
#   'Max Temp': 84.15,
#   'Humidity': 49,
#   'Wind Speed': 4.43,
#   'Cloudiness': 27,
#   'Country': 'MX'},
#  {'City': 'Porbandar',
#   'Lat': 21.64,
#   'Lng': 69.61,
#   'Max Temp': 78.89,
#   'Humidity': 43,
#   'Wind Speed': 6.64,
#   'Cloudiness': 0,
#   'Country': 'IN'},
#  {'City': 'Micheweni',
#   'Lat': -4.97,
#   'Lng': 39.83,
#   'Max Temp': 77.18,
#   'Humidity': 81,
#   'Wind Speed': 9.19,
#   'Cloudiness': 0,
#   'Country': 'TZ'},
#  {'City': 'Alice Springs',
#   'Lat': -23.7,
#   'Lng': 133.88,
#   'Max Temp': 78.8,
#   'Humidity': 13,
#   'Wind Speed': 7.72,
#   'Cloudiness': 0,
#   'Country': 'AU'},
#  {'City': 'Road Town',
#   'Lat': 18.42,
#   'Lng': -64.62,
#   'Max Temp': 82,
#   'Humidity': 74,
#   'Wind Speed': 5.82,
#   'Cloudiness': 20,
#   'Country': 'VG'},
#  {'City': 'Talaya',
#   'Lat': 61.38,
#   'Lng': 152.75,
#   'Max Temp': 11.37,
#   'Humidity': 93,
#   'Wind Speed': 8.95,
#   'Cloudiness': 100,
#   'Country': 'RU'},
#  {'City': 'Denpasar',
#   'Lat': -8.65,
#   'Lng': 115.22,
#   'Max Temp': 78.48,
#   'Humidity': 76,
#   'Wind Speed': 3.06,
#   'Cloudiness': 24,
#   'Country': 'ID'},
#  {'City': 'Salta',
#   'Lat': -24.79,
#   'Lng': -65.41,
#   'Max Temp': 82.4,
#   'Humidity': 24,
#   'Wind Speed': 5.82,
#   'Cloudiness': 0,
#   'Country': 'AR'},
#  {'City': 'Adrar',
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Max Temp': 80.74,
#   'Humidity': 17,
#   'Wind Speed': 9.04,
#   'Cloudiness': 0,
#   'Country': 'MR'},
#  {'City': 'Palu',
#   'Lat': -0.89,
#   'Lng': 119.87,
#   'Max Temp': 78.67,
#   'Humidity': 72,
#   'Wind Speed': 1.99,
#   'Cloudiness': 93,
#   'Country': 'ID'},
#  {'City': 'Lich',
#   'Lat': 50.52,
#   'Lng': 8.82,
#   'Max Temp': 46.99,
#   'Humidity': 85,
#   'Wind Speed': 1.01,
#   'Cloudiness': 66,
#   'Country': 'DE'},
#  {'City': 'Newport',
#   'Lat': 51.59,
#   'Lng': -3,
#   'Max Temp': 41,
#   'Humidity': 94,
#   'Wind Speed': 4.21,
#   'Cloudiness': 26,
#   'Country': 'GB'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Wind Speed  Cloudiness  \
# 0          Fortuna  40.60 -124.16     66.99        77        3.31           1
# 1          Cordoba -31.41  -64.18     77.00        20       13.87           0
# 2        Mahebourg -20.41   57.70     71.60        73        2.24          75
# 3  Arraial Do Cabo -22.97  -42.03     70.45        73       17.43          90
# 4           Kodiak  57.79 -152.41     28.40        42       21.92           1
# 5    San Policarpo  12.18  125.51     79.74        83        6.26         100
# 6         Hermanus -34.42   19.23     64.00        90       12.71          77
# 7            Vaini -21.20 -175.20     80.60        78       13.87          20
# 8     Nova Olimpia -14.80  -57.29     84.06        45        1.88          42
# 9       Nanortalik  60.14  -45.24     39.16        84       17.58         100
#
#   Country
# 0      US
# 1      AR
# 2      MU
# 3      BR
# 4      US
# 5      PH
# 6      ZA
# 7      TO
# 8      BR
# 9      GL

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

# Assign city_data_df the new column order.
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Fortuna      US  40.60 -124.16     66.99        77           1
# 1          Cordoba      AR -31.41  -64.18     77.00        20           0
# 2        Mahebourg      MU -20.41   57.70     71.60        73          75
# 3  Arraial Do Cabo      BR -22.97  -42.03     70.45        73          90
# 4           Kodiak      US  57.79 -152.41     28.40        42           1
# 5    San Policarpo      PH  12.18  125.51     79.74        83         100
# 6         Hermanus      ZA -34.42   19.23     64.00        90          77
# 7            Vaini      TO -21.20 -175.20     80.60        78          20
# 8     Nova Olimpia      BR -14.80  -57.29     84.06        45          42
# 9       Nanortalik      GL  60.14  -45.24     39.16        84         100
#
#    Wind Speed
# 0        3.31
# 1       13.87
# 2        2.24
# 3       17.43
# 4       21.92
# 5        6.26
# 6       12.71
# 7       13.87
# 8        1.88
# 9       17.58

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time

# Get today's date in seconds 
# time.time() output = time in sec since 1/1/1970 as floating point decimal)
# strftime("%x") converts the output to a date
today = time.strftime("%x")
today
# Out:
# '11/03/20'

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Dependencies and Setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create an equal number of latitudes and temperatures.
lats = [42.5, 43.9, 8.1, 36.8, 79.9, 69.1, 25.7, 15.3, 12.7, 64.5]
temps = [80.5, 75.3, 90.9, 90.0, 40.4, 62.3, 85.4, 79.6, 72.5, 72.0]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(lats, temps)
# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
print(f"The p-value is: {p_value:.3f}")
# Out:
# y = -0.45x + 92.94
# The p-value is: 0.011

# %%
# Calculate the regression line "y values" from the slope and intercept.
regress_values = [(lat * slope + intercept) for lat in lats]

# %%
# Import Matplotlib.
import matplotlib.pyplot as plt
# Create a scatter plot of the x and y values.
plt.scatter(lats,temps)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(lats,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City          Atuona
# Country           PF
# Lat             -9.8
# Lng          -139.03
# Max Temp       77.85
# Humidity          73
# Cloudiness        14
# Wind Speed     17.76
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 681    False
# 682     True
# 683    False
# 684     True
# 685     True
# Name: Lat, Length: 686, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Fortuna      US  40.60 -124.16     66.99        77           1
# 4           Kodiak      US  57.79 -152.41     28.40        42           1
# 5    San Policarpo      PH  12.18  125.51     79.74        83         100
# 9       Nanortalik      GL  60.14  -45.24     39.16        84         100
# 12         College      US  64.86 -147.80    -13.00        75          20
# ..             ...     ...    ...     ...       ...       ...         ...
# 678      Road Town      VG  18.42  -64.62     82.00        74          20
# 679         Talaya      RU  61.38  152.75     11.37        93         100
# 682          Adrar      MR  20.50  -10.07     80.74        17           0
# 684           Lich      DE  50.52    8.82     46.99        85          66
# 685        Newport      GB  51.59   -3.00     41.00        94          26
#
#      Wind Speed
# 0          3.31
# 4         21.92
# 5          6.26
# 9         17.58
# 12         0.58
# ..          ...
# 678        5.82
# 679        8.95
# 682        9.04
# 684        1.01
# 685        4.21
#
# [462 rows x 8 columns]

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemispher \n for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))
